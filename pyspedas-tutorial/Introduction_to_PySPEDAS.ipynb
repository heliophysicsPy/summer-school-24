# %% [markdown]
# # Introduction to PySPEDAS
#
# **By Jim Lewis, Berkeley Space Sciences Lab - jwl@ssl.berkeley.edu**
#
# - PySPEDAS: https://pyspedas.readthedocs.io/
# - PyTplot: https://pytplot.readthedocs.io/en/matplotlib-backend/
#
#
# A little history:
# - `tplot` started as an IDL project in 1995, by Davin Larson, and is the core of SPEDAS (and now PySPEDAS)
# - in 2017, some developers on the MAVEN team created an initial Python version, using Qt as a back-end for creating figures
# - in late 2021, development began on a `matplotlib` version, which is what we're using in this notebook

# %% [markdown]
# We have preloaded the data we'll be using with PySPEDAS during PyHC Summer School, to avoid overloading the various data servers we would otherwise need to contact.  We'll set the SPEDAS_DATA_DIR environment variable to the data cache directory.

# %%
import os
os.environ["SPEDAS_DATA_DIR"] = "/home/jovyan/scratch_space/pyspedas_data"

# %% [markdown]
# ### Example 1: A minimal PySPEDAS example ###
#
# We'll import the top level pyspedas and pytplot modules.  We'll also import a few frequently-used tools (like tplot) to avoid repetition.

# %%
import pyspedas
import pytplot
from pytplot import tplot

# %% [markdown]
# We'll set a time range corresponding to the date of the event we're studying.

# %%
trange = ['2023-03-24', '2023-03-25']

# %% [markdown]
# Now we'll load some THEMIS-A Fluxgate Magnetometer (FGM) data and plot it.

# %%
fgm_vars = pyspedas.themis.fgm(probe='a',trange=trange)
print(fgm_vars)
tplot('tha_fgs_gse')
# Out:
# 17-May-24 06:54:09: Downloading remote index: http://themis.ssl.berkeley.edu/data/themis/tha/l2/fgm/2023/
# 17-May-24 06:54:09: File is current: themis_data/tha/l2/fgm/2023/tha_l2_fgm_20230324_v01.cdf
# ['tha_fgs_btotal', 'tha_fgs_gse', 'tha_fgs_gsm', 'tha_fgs_dsl', 'tha_fgl_btotal', 'tha_fgl_gse', 'tha_fgl_gsm', 'tha_fgl_dsl', 'tha_fgl_ssl', 'tha_fgh_btotal', 'tha_fgh_gse', 'tha_fgh_gsm', 'tha_fgh_dsl', 'tha_fgh_ssl', 'tha_fge_btotal', 'tha_fge_gse', 'tha_fge_gsm', 'tha_fge_dsl', 'tha_fge_ssl']

# %% [markdown]
# A few things to note about this example:
#
# Many of the PySPEDAS load routines follow the naming convention pyspedas.mission.instrument.
#
# Parameters to the load routines are fairly standardized, and usually have sensible defaults.
# In this case, we got all the relevant variables (including several choices of time resolution and coordinate systems) from the THEMIS-A L2 FGM data set.
#
# Most load routines return a list of the tplot variables loaded.
#
# We didn't have to set any axis titles, tick mark spacing, data ranges, or legends for the plot!
# Many of the plot options are taken from metadata in the underlying data files; other attributes are initialized with reasonable defaults.

# %% [markdown]
# Tplot variables are the main data structure in PySPEDAS.  A tplot variable is essentially a container for timestamps, data arrays, and metadata (including plot options).  The underlying data structures are mapped to strings, and it is actually the strings or lists of strings that are passed around between PySPEDAS tools.
#
# Let's take a closer look at some of the tplot variables produced by this load routine call.
#
# We can see a list of loaded variables with the routine pytplot.tplot_names():

# %%
pytplot.tplot_names()
# Out:
# 0 : tha_fgs_btotal
# 1 : tha_fgs_gse
# 2 : tha_fgs_gsm
# 3 : tha_fgs_dsl
# 4 : tha_fgl_btotal
# 5 : tha_fgl_gse
# 6 : tha_fgl_gsm
# 7 : tha_fgl_dsl
# 8 : tha_fgl_ssl
# 9 : tha_fgh_btotal
# 10 : tha_fgh_gse
# 11 : tha_fgh_gsm
# 12 : tha_fgh_dsl
# 13 : tha_fgh_ssl
# 14 : tha_fge_btotal
# 15 : tha_fge_gse
# 16 : tha_fge_gsm
# 17 : tha_fge_dsl
# 18 : tha_fge_ssl
# 19 : tha_peif_data_quality
# 20 : tha_peef_data_quality
# 21 : tha_peir_data_quality
# 22 : tha_peer_data_quality
# 23 : tha_peib_data_quality
# 24 : tha_peeb_data_quality
# 25 : tha_peif_density
# 26 : tha_peif_avgtemp
# 27 : tha_peif_vthermal
# 28 : tha_peif_sc_pot
# 29 : tha_peif_en_eflux
# 30 : tha_peif_t3
# 31 : tha_peif_magt3
# 32 : tha_peif_ptens
# 33 : tha_peif_mftens
# 34 : tha_peif_flux
# 35 : tha_peif_symm
# 36 : tha_peif_symm_ang
# 37 : tha_peif_magf
# 38 : tha_peif_velocity_dsl
# 39 : tha_peif_velocity_gse
# 40 : tha_peif_velocity_gsm
# 41 : tha_peef_density
# 42 : tha_peef_avgtemp
# 43 : tha_peef_vthermal
# 44 : tha_peef_sc_pot
# 45 : tha_peef_en_eflux
# 46 : tha_peef_t3
# 47 : tha_peef_magt3
# 48 : tha_peef_ptens
# 49 : tha_peef_mftens
# 50 : tha_peef_flux
# 51 : tha_peef_symm
# 52 : tha_peef_symm_ang
# 53 : tha_peef_magf
# 54 : tha_peef_velocity_dsl
# 55 : tha_peef_velocity_gse
# 56 : tha_peef_velocity_gsm
# 57 : tha_peir_density
# 58 : tha_peir_avgtemp
# 59 : tha_peir_vthermal
# 60 : tha_peir_sc_pot
# 61 : tha_peir_en_eflux
# 62 : tha_peir_t3
# 63 : tha_peir_magt3
# 64 : tha_peir_ptens
# 65 : tha_peir_mftens
# 66 : tha_peir_flux
# 67 : tha_peir_symm
# 68 : tha_peir_symm_ang
# 69 : tha_peir_magf
# 70 : tha_peir_velocity_dsl
# 71 : tha_peir_velocity_gse
# 72 : tha_peir_velocity_gsm
# 73 : tha_peer_density
# 74 : tha_peer_avgtemp
# 75 : tha_peer_vthermal
# 76 : tha_peer_sc_pot
# 77 : tha_peer_en_eflux
# 78 : tha_peer_t3
# 79 : tha_peer_magt3
# 80 : tha_peer_ptens
# 81 : tha_peer_mftens
# 82 : tha_peer_flux
# 83 : tha_peer_symm
# 84 : tha_peer_symm_ang
# 85 : tha_peer_magf
# 86 : tha_peer_velocity_dsl
# 87 : tha_peer_velocity_gse
# 88 : tha_peer_velocity_gsm
# 89 : tha_peib_density
# 90 : tha_peib_avgtemp
# 91 : tha_peib_vthermal
# 92 : tha_peib_sc_pot
# 93 : tha_peib_en_eflux
# 94 : tha_peib_t3
# 95 : tha_peib_magt3
# 96 : tha_peib_ptens
# 97 : tha_peib_mftens
# 98 : tha_peib_flux
# 99 : tha_peib_symm
# 100 : tha_peib_symm_ang
# 101 : tha_peib_magf
# 102 : tha_peib_velocity_dsl
# 103 : tha_peib_velocity_gse
# 104 : tha_peib_velocity_gsm
# 105 : tha_peeb_density
# 106 : tha_peeb_avgtemp
# 107 : tha_peeb_vthermal
# 108 : tha_peeb_sc_pot
# 109 : tha_peeb_en_eflux
# 110 : tha_peeb_t3
# 111 : tha_peeb_magt3
# 112 : tha_peeb_ptens
# 113 : tha_peeb_mftens
# 114 : tha_peeb_flux
# 115 : tha_peeb_symm
# 116 : tha_peeb_symm_ang
# 117 : tha_peeb_magf
# 118 : tha_peeb_velocity_dsl
# 119 : tha_peeb_velocity_gse
# 120 : tha_peeb_velocity_gsm
# 121 : tha_eesa_solarwind_flag
# 122 : tha_iesa_solarwind_flag
# 123 : erg_orb_l2_pos_llr
# 124 : erg_orb_l2_pos_gse
# 125 : erg_orb_l2_pos_gsm
# 126 : erg_orb_l2_pos_sm
# 127 : erg_orb_l2_pos_rmlatmlt
# 128 : erg_orb_l2_pos_eq
# 129 : erg_orb_l2_pos_iono_north
# 130 : erg_orb_l2_pos_iono_south
# 131 : erg_orb_l2_pos_blocal
# 132 : erg_orb_l2_pos_blocal_mag
# 133 : erg_orb_l2_pos_beq
# 134 : erg_orb_l2_pos_beq_mag
# 135 : erg_orb_l2_pos_Lm
# 136 : erg_orb_l2_vel_gse
# 137 : erg_orb_l2_vel_gsm
# 138 : erg_orb_l2_vel_sm
# 139 : erg_orb_l2_spn_num
# 140 : erg_orb_l2_man_prep_flag
# 141 : erg_orb_l2_man_on_flag
# 142 : erg_orb_l2_eclipse_flag
# 143 : IMF
# 144 : PLS
# 145 : IMF_PTS
# 146 : PLS_PTS
# 147 : percent_interp
# 148 : Timeshift
# 149 : RMS_Timeshift
# 150 : RMS_phase
# 151 : Time_btwn_obs
# 152 : F
# 153 : BX_GSE
# 154 : BY_GSE
# 155 : BZ_GSE
# 156 : BY_GSM
# 157 : BZ_GSM
# 158 : RMS_SD_B
# 159 : RMS_SD_fld_vec
# 160 : flow_speed
# 161 : Vx
# 162 : Vy
# 163 : Vz
# 164 : proton_density
# 165 : T
# 166 : NaNp_Ratio
# 167 : Pressure
# 168 : E
# 169 : Beta
# 170 : Mach_num
# 171 : Mgs_mach_num
# 172 : x
# 173 : y
# 174 : z
# 175 : BSN_x
# 176 : BSN_y
# 177 : BSN_z
# 178 : AE_INDEX
# 179 : AL_INDEX
# 180 : AU_INDEX
# 181 : SYM_D
# 182 : SYM_H
# 183 : ASY_D
# 184 : ASY_H
# 185 : thg_mag_atha
# 186 : thg_mag_fsmi
# 187 : thg_mag_fykn
# 188 : thg_mag_fsmi_subtract_median
# ['tha_fgs_btotal',
#  'tha_fgs_gse',
#  'tha_fgs_gsm',
#  'tha_fgs_dsl',
#  'tha_fgl_btotal',
#  'tha_fgl_gse',
#  'tha_fgl_gsm',
#  'tha_fgl_dsl',
#  'tha_fgl_ssl',
#  'tha_fgh_btotal',
#  'tha_fgh_gse',
#  'tha_fgh_gsm',
#  'tha_fgh_dsl',
#  'tha_fgh_ssl',
#  'tha_fge_btotal',
#  'tha_fge_gse',
#  'tha_fge_gsm',
#  'tha_fge_dsl',
#  'tha_fge_ssl',
#  'tha_peif_data_quality',
#  'tha_peef_data_quality',
#  'tha_peir_data_quality',
#  'tha_peer_data_quality',
#  'tha_peib_data_quality',
#  'tha_peeb_data_quality',
#  'tha_peif_density',
#  'tha_peif_avgtemp',
#  'tha_peif_vthermal',
#  'tha_peif_sc_pot',
#  'tha_peif_en_eflux',
#  'tha_peif_t3',
#  'tha_peif_magt3',
#  'tha_peif_ptens',
#  'tha_peif_mftens',
#  'tha_peif_flux',
#  'tha_peif_symm',
#  'tha_peif_symm_ang',
#  'tha_peif_magf',
#  'tha_peif_velocity_dsl',
#  'tha_peif_velocity_gse',
#  'tha_peif_velocity_gsm',
#  'tha_peef_density',
#  'tha_peef_avgtemp',
#  'tha_peef_vthermal',
#  'tha_peef_sc_pot',
#  'tha_peef_en_eflux',
#  'tha_peef_t3',
#  'tha_peef_magt3',
#  'tha_peef_ptens',
#  'tha_peef_mftens',
#  'tha_peef_flux',
#  'tha_peef_symm',
#  'tha_peef_symm_ang',
#  'tha_peef_magf',
#  'tha_peef_velocity_dsl',
#  'tha_peef_velocity_gse',
#  'tha_peef_velocity_gsm',
#  'tha_peir_density',
#  'tha_peir_avgtemp',
#  'tha_peir_vthermal',
#  'tha_peir_sc_pot',
#  'tha_peir_en_eflux',
#  'tha_peir_t3',
#  'tha_peir_magt3',
#  'tha_peir_ptens',
#  'tha_peir_mftens',
#  'tha_peir_flux',
#  'tha_peir_symm',
#  'tha_peir_symm_ang',
#  'tha_peir_magf',
#  'tha_peir_velocity_dsl',
#  'tha_peir_velocity_gse',
#  'tha_peir_velocity_gsm',
#  'tha_peer_density',
#  'tha_peer_avgtemp',
#  'tha_peer_vthermal',
#  'tha_peer_sc_pot',
#  'tha_peer_en_eflux',
#  'tha_peer_t3',
#  'tha_peer_magt3',
#  'tha_peer_ptens',
#  'tha_peer_mftens',
#  'tha_peer_flux',
#  'tha_peer_symm',
#  'tha_peer_symm_ang',
#  'tha_peer_magf',
#  'tha_peer_velocity_dsl',
#  'tha_peer_velocity_gse',
#  'tha_peer_velocity_gsm',
#  'tha_peib_density',
#  'tha_peib_avgtemp',
#  'tha_peib_vthermal',
#  'tha_peib_sc_pot',
#  'tha_peib_en_eflux',
#  'tha_peib_t3',
#  'tha_peib_magt3',
#  'tha_peib_ptens',
#  'tha_peib_mftens',
#  'tha_peib_flux',
#  'tha_peib_symm',
#  'tha_peib_symm_ang',
#  'tha_peib_magf',
#  'tha_peib_velocity_dsl',
#  'tha_peib_velocity_gse',
#  'tha_peib_velocity_gsm',
#  'tha_peeb_density',
#  'tha_peeb_avgtemp',
#  'tha_peeb_vthermal',
#  'tha_peeb_sc_pot',
#  'tha_peeb_en_eflux',
#  'tha_peeb_t3',
#  'tha_peeb_magt3',
#  'tha_peeb_ptens',
#  'tha_peeb_mftens',
#  'tha_peeb_flux',
#  'tha_peeb_symm',
#  'tha_peeb_symm_ang',
#  'tha_peeb_magf',
#  'tha_peeb_velocity_dsl',
#  'tha_peeb_velocity_gse',
#  'tha_peeb_velocity_gsm',
#  'tha_eesa_solarwind_flag',
#  'tha_iesa_solarwind_flag',
#  'erg_orb_l2_pos_llr',
#  'erg_orb_l2_pos_gse',
#  'erg_orb_l2_pos_gsm',
#  'erg_orb_l2_pos_sm',
#  'erg_orb_l2_pos_rmlatmlt',
#  'erg_orb_l2_pos_eq',
#  'erg_orb_l2_pos_iono_north',
#  'erg_orb_l2_pos_iono_south',
#  'erg_orb_l2_pos_blocal',
#  'erg_orb_l2_pos_blocal_mag',
#  'erg_orb_l2_pos_beq',
#  'erg_orb_l2_pos_beq_mag',
#  'erg_orb_l2_pos_Lm',
#  'erg_orb_l2_vel_gse',
#  'erg_orb_l2_vel_gsm',
#  'erg_orb_l2_vel_sm',
#  'erg_orb_l2_spn_num',
#  'erg_orb_l2_man_prep_flag',
#  'erg_orb_l2_man_on_flag',
#  'erg_orb_l2_eclipse_flag',
#  'IMF',
#  'PLS',
#  'IMF_PTS',
#  'PLS_PTS',
#  'percent_interp',
#  'Timeshift',
#  'RMS_Timeshift',
#  'RMS_phase',
#  'Time_btwn_obs',
#  'F',
#  'BX_GSE',
#  'BY_GSE',
#  'BZ_GSE',
#  'BY_GSM',
#  'BZ_GSM',
#  'RMS_SD_B',
#  'RMS_SD_fld_vec',
#  'flow_speed',
#  'Vx',
#  'Vy',
#  'Vz',
#  'proton_density',
#  'T',
#  'NaNp_Ratio',
#  'Pressure',
#  'E',
#  'Beta',
#  'Mach_num',
#  'Mgs_mach_num',
#  'x',
#  'y',
#  'z',
#  'BSN_x',
#  'BSN_y',
#  'BSN_z',
#  'AE_INDEX',
#  'AL_INDEX',
#  'AU_INDEX',
#  'SYM_D',
#  'SYM_H',
#  'ASY_D',
#  'ASY_H',
#  'thg_mag_atha',
#  'thg_mag_fsmi',
#  'thg_mag_fykn',
#  'thg_mag_fsmi_subtract_median']

# %% [markdown]
# To get access to the underlying timestamp or data arrays, or the metadata dictionary,
# we can use pytplot.get_data().
#
# pytplot.time_string() is useful for generating human-readable timestamps.

# %%
from pytplot import get_data, time_string

# By default, get_data returns a tuple with named fields 'times', 'y', 
# and possibly additional fields for spectrograms or higher dimensional data arrays.
fgs_dat = get_data('tha_fgs_gse')
print(time_string(fgs_dat.times[0:3]))
print(fgs_dat.y[0:3])

# get_data can also return a dictionary containing the variable's metadata, plot options, etc.
fgs_md = get_data('tha_fgs_gse', metadata=True)
print(fgs_md.keys())
print(fgs_md['plot_options']['yaxis_opt'])
# Out:
# ['2023-03-24 00:01:04.462111', '2023-03-24 00:01:07.203537', '2023-03-24 00:01:09.944960']
# [[ -9.648484 -12.33979  -12.768709]
#  [ -9.629018 -12.026798 -12.91995 ]
#  [-10.109423 -11.871632 -13.101343]]
# dict_keys(['CDF', 'data_att', 'plot_options'])
# {'axis_label': 'THA FGS', 'crosshair': 'Y', 'y_axis_type': 'linear', 'y_range': [-16843.938, 18382.479], 'axis_subtitle': '[nT GSE]', 'legend_names': ['Bx GSE', 'By GSE', 'Bz GSE']}

# %% [markdown]
# To find the supported load routines and keywords, see our documentation: https://pyspedas.readthedocs.io/
#
# You can also see the supported options by calling `help` on the load routine you're interested in

# %%
help(pyspedas.themis.fgm)
# Out:
# Help on function fgm in module pyspedas.themis.spacecraft.fields.fgm:
#
# fgm(trange=['2007-03-23', '2007-03-24'], probe='c', level='l2', suffix='', get_support_data=False, varformat=None, coord=None, varnames=[], downloadonly=False, notplot=False, no_update=False, time_clip=False)
#     This function loads Fluxgate magnetometer (FGM) data
#
#     Parameters
#     ----------
#         trange : list of str
#             time range of interest [starttime, endtime] with the format
#             'YYYY-MM-DD','YYYY-MM-DD'] or to specify more or less than a day
#             ['YYYY-MM-DD/hh:mm:ss','YYYY-MM-DD/hh:mm:ss']
#             Default: ['2007-03-23', '2007-03-24']
#
#         probe: str or list of str
#             Spacecraft probe letter(s) ('a', 'b', 'c', 'd' and/or 'e')
#             Default: 'c'
#
#         level: str
#             Data level; Valid options: 'l1', 'l2'
#             Default: 'l2'
#
#         suffix: str
#             The tplot variable names will be given this suffix.
#             Default: no suffix
#
#         get_support_data: bool
#             Data with an attribute "VAR_TYPE" with a value of "support_data"
#             will be loaded into tplot.
#             Default: False; only loads data with a "VAR_TYPE" attribute of "data"
#
#         varformat: str
#             The file variable formats to load into tplot.  Wildcard character
#             "*" is accepted.
#             Default: None; all variables are loaded
#
#         varnames: list of str
#             List of variable names to load
#             Default: Empty list, so all data variables are loaded
#
#         downloadonly: bool
#             Set this flag to download the CDF files, but not load them into
#             tplot variables
#             Default: False
#
#         notplot: bool
#             Return the data in hash tables instead of creating tplot variables
#             Default: False
#
#         no_update: bool
#             If set, only load data from your local cache
#             Default: False
#
#         time_clip: bool
#             Time clip the variables to exactly the range specified
#             in the trange keyword
#             Default: False
#
#     Returns
#     -------
#         List of str
#         List of tplot variables created
#         Empty list if no data
#
#     Example
#     -------
#         import pyspedas
#         from pytplot import tplot
#         >>> fgm_vars = pyspedas.themis.fgm(probe='d', trange=['2013-11-5', '2013-11-6'])
#         >>> tplot(['thd_fgs_btotal', 'thd_fgs_gse'])

# %% [markdown]
# # THEMIS ESA (Electrostatic Analyzer) data
#
# Now we'll load some THEMIS-A data from the ESA instrument.   This is a good example of a spectrogram plot.

# %%
esa_vars = pyspedas.themis.esa(probe='a', trange=trange)
print(esa_vars)

# PEEF = ESA fast survey electrons, PEIF = ESA fast survey ions
tplot(['tha_peef_en_eflux','tha_peef_velocity_dsl','tha_peif_en_eflux', 'tha_peif_velocity_dsl'])
# Out:
# 17-May-24 06:53:47: Downloading remote index: http://themis.ssl.berkeley.edu/data/themis/tha/l2/esa/2023/
# 17-May-24 06:53:47: File is current: themis_data/tha/l2/esa/2023/tha_l2_esa_20230324_v01.cdf
# 17-May-24 06:53:47: Variable tha_peer_symm_angQ not marked as VIRTUAL, but has FUNCT and COMPONENT_0 attributes; skipping
# 17-May-24 06:53:47: Variable tha_peer_magfQ not marked as VIRTUAL, but has FUNCT and COMPONENT_0 attributes; skipping
# 17-May-24 06:53:47: Variable tha_peer_velocity_dslQ not marked as VIRTUAL, but has FUNCT and COMPONENT_0 attributes; skipping
# 17-May-24 06:53:47: Variable tha_peer_velocity_gseQ not marked as VIRTUAL, but has FUNCT and COMPONENT_0 attributes; skipping
# 17-May-24 06:53:47: Variable tha_peer_velocity_gsmQ not marked as VIRTUAL, but has FUNCT and COMPONENT_0 attributes; skipping
# 17-May-24 06:53:47: Variable tha_peer_modeQ not marked as VIRTUAL, but has FUNCT and COMPONENT_0 attributes; skipping
# ['tha_peif_data_quality', 'tha_peef_data_quality', 'tha_peir_data_quality', 'tha_peer_data_quality', 'tha_peib_data_quality', 'tha_peeb_data_quality', 'tha_peif_density', 'tha_peif_avgtemp', 'tha_peif_vthermal', 'tha_peif_sc_pot', 'tha_peif_en_eflux', 'tha_peif_t3', 'tha_peif_magt3', 'tha_peif_ptens', 'tha_peif_mftens', 'tha_peif_flux', 'tha_peif_symm', 'tha_peif_symm_ang', 'tha_peif_magf', 'tha_peif_velocity_dsl', 'tha_peif_velocity_gse', 'tha_peif_velocity_gsm', 'tha_peef_density', 'tha_peef_avgtemp', 'tha_peef_vthermal', 'tha_peef_sc_pot', 'tha_peef_en_eflux', 'tha_peef_t3', 'tha_peef_magt3', 'tha_peef_ptens', 'tha_peef_mftens', 'tha_peef_flux', 'tha_peef_symm', 'tha_peef_symm_ang', 'tha_peef_magf', 'tha_peef_velocity_dsl', 'tha_peef_velocity_gse', 'tha_peef_velocity_gsm', 'tha_peir_density', 'tha_peir_avgtemp', 'tha_peir_vthermal', 'tha_peir_sc_pot', 'tha_peir_en_eflux', 'tha_peir_t3', 'tha_peir_magt3', 'tha_peir_ptens', 'tha_peir_mftens', 'tha_peir_flux', 'tha_peir_symm', 'tha_peir_symm_ang', 'tha_peir_magf', 'tha_peir_velocity_dsl', 'tha_peir_velocity_gse', 'tha_peir_velocity_gsm', 'tha_peer_density', 'tha_peer_avgtemp', 'tha_peer_vthermal', 'tha_peer_sc_pot', 'tha_peer_en_eflux', 'tha_peer_t3', 'tha_peer_magt3', 'tha_peer_ptens', 'tha_peer_mftens', 'tha_peer_flux', 'tha_peer_symm', 'tha_peer_symm_ang', 'tha_peer_magf', 'tha_peer_velocity_dsl', 'tha_peer_velocity_gse', 'tha_peer_velocity_gsm', 'tha_peib_density', 'tha_peib_avgtemp', 'tha_peib_vthermal', 'tha_peib_sc_pot', 'tha_peib_en_eflux', 'tha_peib_t3', 'tha_peib_magt3', 'tha_peib_ptens', 'tha_peib_mftens', 'tha_peib_flux', 'tha_peib_symm', 'tha_peib_symm_ang', 'tha_peib_magf', 'tha_peib_velocity_dsl', 'tha_peib_velocity_gse', 'tha_peib_velocity_gsm', 'tha_peeb_density', 'tha_peeb_avgtemp', 'tha_peeb_vthermal', 'tha_peeb_sc_pot', 'tha_peeb_en_eflux', 'tha_peeb_t3', 'tha_peeb_magt3', 'tha_peeb_ptens', 'tha_peeb_mftens', 'tha_peeb_flux', 'tha_peeb_symm', 'tha_peeb_symm_ang', 'tha_peeb_magf', 'tha_peeb_velocity_dsl', 'tha_peeb_velocity_gse', 'tha_peeb_velocity_gsm', 'tha_eesa_solarwind_flag', 'tha_iesa_solarwind_flag']

# %% [markdown]
# Let's take a look at one of the spectrogram variables, 'tha_peif_en_eflux'.

# %%
import numpy as np
esa_eflux_data = get_data('tha_peif_en_eflux')
print("Timestamps:")
print(pytplot.time_string(esa_eflux_data.times[0:3]))
print("First data value(s):")
print(esa_eflux_data.y[0,:])
print("First v values(s):")
print(esa_eflux_data.v[0,:])
print("Shape of times array:",np.shape(esa_eflux_data.times))
print("Shape of data values array:", np.shape(esa_eflux_data.y))
print("Shape of v (bin values) array:",np.shape(esa_eflux_data.v))
# Out:
# Timestamps:
# ['2023-03-24 00:00:03.061822', '2023-03-24 00:01:30.787401', '2023-03-24 00:02:58.512975']
# First data value(s):
# [           nan 6.15290332e+03 5.73440137e+03 2.56426440e+03
#  5.18128906e+03 1.33006091e+03 5.41965283e+03 1.34188008e+04
#  9.80961484e+04 4.04959850e+06 2.12209656e+05 1.55885430e+07
#  4.39665000e+07 5.05284375e+05 1.42198467e+04 6.87176562e+03
#  3.87914087e+03 4.48261426e+03 2.50773999e+03 1.25872205e+03
#  2.34443140e+03 0.00000000e+00 1.82727820e+03 0.00000000e+00
#  2.18389990e+03 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  6.25864404e+03 0.00000000e+00 5.92535706e+02 0.00000000e+00]
# First v values(s):
# [2.5213438e+04 2.1296297e+04 1.6178354e+04 1.2290454e+04 9.3367285e+03
#  7.0928662e+03 5.3884238e+03 4.0933552e+03 3.1095496e+03 2.3627498e+03
#  1.7944740e+03 1.3631693e+03 1.0353623e+03 7.8719855e+02 5.9751678e+02
#  4.5362027e+02 3.4512076e+02 2.6201477e+02 1.9930051e+02 1.5120676e+02
#  1.1504025e+02 8.7723000e+01 6.6561752e+01 5.0402252e+01 3.8475002e+01
#  2.9241001e+01 2.2315500e+01 1.6544250e+01 1.2696751e+01 1.0003500e+01
#  7.3102503e+00 5.7712502e+00]
# Shape of times array: (746,)
# Shape of data values array: (746, 32)
# Shape of v (bin values) array: (746, 32)

# %% [markdown]
# There are 746 timestamps.  Each data point has 32 energy bins, with the bin values (in eV) along the Y axis.
#
# The data values in each energy bin are mapped to colors (what we call the "z-axis" for a spectogram variable).
#
# The tuple returned by get_data for this variable has an extra component, 'v', representing the bin values along the Y axis. Note that v also has shape 746 x 32.  The bin values are allowed to vary over time, and PySPEDAS will render them correctly as long as the metadata in the underlying data file follows the standard conventions.

# %% [markdown]
# # Orbit data for the ERG (Arase) satellite
#
# Let's look at a different mission, JAXA's Arase probe.   We'll load and plot the orbit data
# for the time range of interest.

# %%
erg_orb_vars = pyspedas.erg.orb(trange=trange)
tplot('erg_orb_l2_pos_gse')
# Out:
# 17-May-24 06:53:51: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2023/
# 17-May-24 06:53:53: File is current: erg_data/satellite/erg/orb/def/2023/erg_orb_l2_20230324_v04.cdf
#
# **************************************************************************
# ['Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data']
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************

# %%
erg_orb_vars
# Out:
# ['erg_orb_l2_pos_llr',
#  'erg_orb_l2_pos_gse',
#  'erg_orb_l2_pos_gsm',
#  'erg_orb_l2_pos_sm',
#  'erg_orb_l2_pos_rmlatmlt',
#  'erg_orb_l2_pos_eq',
#  'erg_orb_l2_pos_iono_north',
#  'erg_orb_l2_pos_iono_south',
#  'erg_orb_l2_pos_blocal',
#  'erg_orb_l2_pos_blocal_mag',
#  'erg_orb_l2_pos_beq',
#  'erg_orb_l2_pos_beq_mag',
#  'erg_orb_l2_pos_Lm',
#  'erg_orb_l2_vel_gse',
#  'erg_orb_l2_vel_gsm',
#  'erg_orb_l2_vel_sm',
#  'erg_orb_l2_spn_num',
#  'erg_orb_l2_man_prep_flag',
#  'erg_orb_l2_man_on_flag',
#  'erg_orb_l2_eclipse_flag']

# %% [markdown]
# # OMNIWeb Solar Wind parameters
#
# The OMNIWeb data set includes various solar wind and interplanetary magnetic field measurements that are especially useful as inputs to models of Earth's magnetic field, and as geomagnetic activity indexes.   Here we'll load some OMNI data for the date we're studying, and plot the proton density, flow speed, and dynamic pressure.

# %%
pyspedas.omni.data(trange=trange)
tplot(['proton_density', 'flow_speed', 'Pressure'])
# Out:
# 17-May-24 06:53:53: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/omni/omni_cdaweb/hro2_1min/2023/
# 17-May-24 06:53:54: File is current: omni_data/hro2_1min/2023/omni_hro2_1min_20230301_v01.cdf

# %% [markdown]
# # Ground Magnetometer Data #

# %% [markdown]
# PySPEDAS can load magnetometer data from several networks of ground stations in North America, Europe, Antarctica, and other locations.  Most of them can be accessed via the THEMIS GMAG load routine.

# %%
gmag_vars = pyspedas.themis.gmag(sites=['fsmi', 'fykn', 'atha'], trange=trange)
tplot(gmag_vars)
# Out:
# 17-May-24 06:53:55: Downloading remote index: http://themis.ssl.berkeley.edu/data/themis/thg/l2/mag/fsmi/2023/
# 17-May-24 06:53:56: File is current: themis_data/thg/l2/mag/fsmi/2023/thg_l2_mag_fsmi_20230324_v01.cdf
# 17-May-24 06:53:56: Downloading remote index: http://themis.ssl.berkeley.edu/data/themis/thg/l2/mag/fykn/2023/
# 17-May-24 06:53:56: File is current: themis_data/thg/l2/mag/fykn/2023/thg_l2_mag_fykn_20230324_v01.cdf
# 17-May-24 06:53:56: Downloading remote index: http://themis.ssl.berkeley.edu/data/themis/thg/l2/mag/atha/2023/
# 17-May-24 06:53:56: File is current: themis_data/thg/l2/mag/atha/2023/thg_l2_mag_atha_20230324_v01.cdf

# %% [markdown]
# Let's take a closer look at the FSMI data (Fort Smith, Northwest Territories, Canada).
# The strength of the ambient field makes it hard to see small variations.  PyTplot has a "subtract_median" tool that will help visualize the variations.

# %%
pytplot.subtract_median('thg_mag_fsmi',newname='thg_mag_fsmi_subtract_median')
tplot('thg_mag_fsmi_subtract_median')
# Out:
# 17-May-24 06:53:57: Subtract Median was applied to: thg_mag_fsmi_subtract_median
