# %% [markdown]
# # MMS1 Summary Plot for 2023-03-24 #
#
# A typical first step in a PySPEDAS workflow would be to look at a summary plot for one or more missions, typically showing about a day's worth of data from multiple instruments, and perhaps other related data such as geomagnetic indices, solar wind parameters, ground-based data, or orbit data.
#
# PySPEDAS has an overview plot generator for MMS, so we'll use it to look at data from MMS-1 for the day of the event we're studying, March 24, 2023.
#
# mms_overview_plot takes a date and an MMS probe identifier, and by default plots a full day's worth of data.  In this example, we'll specify a time range. (Note that many of the MMS data products are available as daily files, so choosing a short time interval may not save as much memory and disk space as you might expect.)
#
# #### Note: Due to the large data volume and memory requirements for MMS summary plots, the loading and plotting commands are commented out, and the output will be shown as pre-rendered images.  Otherwise, we risk crashing the environment for everyone.   If you want to try generating your own summary plots, and have 8-12 GB of memory available, feel free to give it a try on your own machine (but please not during summer school week, while we're all sharing a network!)  You could also try running it in a Google Colab environment.

# %%
import os
os.environ["SPEDAS_DATA_DIR"] = "/home/jovyan/scratch_space/pyspedas_data"

# %%
import pyspedas
import pytplot

#pyspedas.mms_overview_plot(trange=['2023-03-24 00:00:00', '2023-03-25 00:00:00'],probe='1',ysize=12, save_png='mms_summary_plot_20230324.png')
# Out:
# 17-May-24 10:29:03: /Users/jwl/PycharmProjects/summer-school-24/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#
# 17-May-24 10:29:04: Downloading remote index: http://themis.ssl.berkeley.edu/data/themis/thg/l1/mag/idx/2023/
# 17-May-24 10:29:04: File is current: themis_data/thg/l1/mag/idx/2023/thg_l1_idx_20230324_v01.cdf
# 17-May-24 10:29:07: Loading pydata/mms1/fgm/srvy/l2/2023/03/mms1_fgm_srvy_l2_20230324_v5.393.0.cdf
# 17-May-24 10:29:10: Loading pydata/mms1/epd-eis/srvy/l2/extof/2023/03/mms1_epd-eis_srvy_l2_extof_20230324_v5.0.100.cdf
# 17-May-24 10:29:12: mms1_epd_eis_srvy_l2_extof_proton_P5_cps_t5 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:12: mms1_epd_eis_srvy_l2_extof_proton_P5_flux_t5 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:12: mms1_epd_eis_srvy_l2_extof_proton_P5_flux_t5_spin contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:13: Problem calculating the spin-average for species: alpha (extof)
# 17-May-24 10:29:13: mms1_epd_eis_srvy_l2_extof_proton_flux_omni contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:13: Error, problem finding the telescopes to calculate omni-directional spectrograms
# 17-May-24 10:29:13: mms1_epd_eis_srvy_l2_extof_proton_flux_omni_spin contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_proton_t0_energy_dminus_spin is currently not in pytplot
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_proton_t0_energy_spin is currently not in pytplot
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_proton_t0_energy_dplus_spin is currently not in pytplot
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_oxygen_t0_energy_dminus_spin is currently not in pytplot
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_oxygen_t0_energy_spin is currently not in pytplot
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_oxygen_t0_energy_dplus_spin is currently not in pytplot
# 17-May-24 10:29:13: Error, problem finding the telescopes to calculate omni-directional spectrograms
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_helium_t0_energy_dminus_spin is currently not in pytplot
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_helium_t0_energy_spin is currently not in pytplot
# 17-May-24 10:29:13: The name mms1_epd_eis_srvy_l2_extof_helium_t0_energy_dplus_spin is currently not in pytplot
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324000000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324020000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324040000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324060000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324140000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324160000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324180000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324200000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/des-moms/2023/03/mms1_fpi_fast_l2_des-moms_20230324220000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324000000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324020000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324040000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324060000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324140000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324160000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324180000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324200000_v3.4.0.cdf
# 17-May-24 10:29:16: Loading pydata/mms1/fpi/fast/l2/dis-moms/2023/03/mms1_fpi_fast_l2_dis-moms_20230324220000_v3.4.0.cdf
# 17-May-24 10:29:18: The name mms1_dis_pitchangdist_lowen_fast is currently not in pytplot
# 17-May-24 10:29:18: The name mms1_dis_pitchangdist_miden_fast is currently not in pytplot
# 17-May-24 10:29:18: The name mms1_dis_pitchangdist_highen_fast is currently not in pytplot
# 17-May-24 10:29:21: Loading pydata/mms1/feeps/srvy/l2/electron/2023/03/mms1_feeps_srvy_l2_electron_20230324000000_v7.2.2.cdf
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_1: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_2: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_3: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_4: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_5: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_9: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_10: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_11: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_centroid_sensorid_12: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_1: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_2: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_3: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_4: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_5: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_9: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_10: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_11: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_lower_bound_sensorid_12: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_1: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_2: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_3: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_4: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_5: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_9: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_10: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_11: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_energy_upper_bound_sensorid_12: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_1: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_2: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_3: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_4: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_5: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_9: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_10: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_11: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_centroid_sensorid_12: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_1: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_2: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_3: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_4: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_5: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_9: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_10: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_11: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_lower_bound_sensorid_12: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_1: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_2: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_3: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_4: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_5: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_9: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_10: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_11: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_energy_upper_bound_sensorid_12: lengths of x (35142) and y (16) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_count_rate_sensorid_1 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_count_rate_sensorid_2 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_count_rate_sensorid_4 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_count_rate_sensorid_11 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_count_rate_sensorid_1 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_count_rate_sensorid_3 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_count_rate_sensorid_11 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_count_rate_sensorid_12 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_intensity_sensorid_1 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_intensity_sensorid_2 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_intensity_sensorid_4 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_intensity_sensorid_11 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_intensity_sensorid_1 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_intensity_sensorid_3 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_intensity_sensorid_11 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_intensity_sensorid_12 contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_1: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_2: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_3: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_4: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_5: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_9: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_10: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_11: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sector_mask_sensorid_12: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_1: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_2: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_3: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_4: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_5: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_9: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_10: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_11: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sector_mask_sensorid_12: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_1: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_2: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_3: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_4: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_5: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_9: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_10: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_11: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_top_sun_contamination_sensorid_12: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_1: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_2: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_3: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_4: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_5: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_9: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_10: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_11: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:22: mms1_epd_feeps_srvy_l2_electron_bottom_sun_contamination_sensorid_12: lengths of x (35142) and y (64) do not match! Mislabeled NRV variable?
# 17-May-24 10:29:25: Loading pydata/mms1/hpca/srvy/l2/moments/2023/03/mms1_hpca_srvy_l2_moments_20230324000000_v4.3.3.cdf
# 17-May-24 10:29:25: Loading pydata/mms1/hpca/srvy/l2/moments/2023/03/mms1_hpca_srvy_l2_moments_20230324060000_v4.3.3.cdf
# 17-May-24 10:29:25: Loading pydata/mms1/hpca/srvy/l2/moments/2023/03/mms1_hpca_srvy_l2_moments_20230324090200_v4.3.3.cdf
# 17-May-24 10:29:25: Loading pydata/mms1/hpca/srvy/l2/moments/2023/03/mms1_hpca_srvy_l2_moments_20230324113300_v4.3.3.cdf
# 17-May-24 10:29:25: Loading pydata/mms1/hpca/srvy/l2/moments/2023/03/mms1_hpca_srvy_l2_moments_20230324120000_v4.3.3.cdf
# 17-May-24 10:29:25: Loading pydata/mms1/hpca/srvy/l2/moments/2023/03/mms1_hpca_srvy_l2_moments_20230324180000_v4.3.3.cdf
# 17-May-24 10:29:28: Loading pydata/mms1/edp/fast/l2/dce/2023/03/mms1_edp_fast_l2_dce_20230324_v3.0.0.cdf
# 17-May-24 10:29:30: /Users/jwl/PycharmProjects/summer-school-24/.venv/lib/python3.9/site-packages/pytplot/MPLPlotter/specplot.py:285: RuntimeWarning: divide by zero encountered in log10
#   zdata = np.log10(out_values)
#
# 17-May-24 10:29:30: /Users/jwl/PycharmProjects/summer-school-24/.venv/lib/python3.9/site-packages/pytplot/MPLPlotter/specplot.py:285: RuntimeWarning: invalid value encountered in log10
#   zdata = np.log10(out_values)
# 17-May-24 10:31:26: MMS overview plot completed.

# %% [markdown]
# # Interpreting the plot #
#
# ![SUMMARY PLOT](mms_summary_plot_20230324.png)
#
# The data displayed in the top panel doesn't come from MMS -- it shows two approximations of the Auroral Electrojet (AE) index.  Production of the definitive AE index from a standard set of ground magnetometer stations can lag by months or years, so it's not useful for near real-time analysis.  Instead, we use a so-called "Kyoto proxy AE" index, derivied from some near-real-time plots available from the Kyoto World Data Center, and a "THEMIS AE index" derived from a set of ground magnetometers operated in conjunction with the THEMIS satellite mission.  Higher values of the AE index indicate more geomagnetic activity.
#
# Panel 2 shows the MMS-1 magnetic field measurements.   The peak indicates when MMS-1 was near perihelion. (This is more useful when zooming into shorter time intervals, or reducing the Y range so the strong fields near perigee don't dominate the plot.)
#
# Panels 3-6 show energy spectrograms from the MMS particle instruments: two panels for protons, then two for electrons.  It looks like are some data gaps around perigee.
#
# Panel 7 shows proton density from the HPCA (Hot Plasma Composition Analyzer) instrument
#
# Panel 8 shows the electric field measurements.
#
# Panel 9 shows electron and ion densities.
#
# Panels 10 and 11 show velocity measurements for protons and oxygen ions from the HPCA instrument.
#
# Several regions of interest can be seen, especially in the particle densities and energies:
#
# 2-5 hours UTC: Multiple inbound bow shock crossings
#
# 5-7 hours UTC: Inbound magnetopause crossings
#
# ~7 hours UTC: Possible reconnection signature (fast ion flows with direction reversal)
#
# ~7-16 hours UTC: Within the magnetosphere
#
# 16-24 hours UTC: Outbound magnetopause and bow shock crossings

# %% [markdown]
# # Inbound magnetopause crossing #
#
# Let's take a closer look at the inbound magnetopause crossing(s).  We'll zoom in on a 8-hour time interval starting at 01:00 UTC, and show the AE index, magnetic field, bulk ion velocity, and particle densities.  We'll also load and plot some OMNI solar wind parameters.

# %%
import pytplot

# We're particularly interested in 'Pressure', the solar wind dynamic pressure from the OMNI dataset, and the proton speed and density.

#pyspedas.omni.data(trange=['2023-03-24', '2023-03-25'])

# Zoom in on the time range of interest
pytplot.timespan('2023-03-24 01:00',8,"hours")

# Make a plot for the restricted time range
#pytplot.tplot(['thg_idx_combined','flow_speed', 'proton_density', 'Pressure', 'mms1_fgm_b_gse_srvy_l2', 'mms1_dis_bulkv_gse_fast','mms1_fpi_density'], save_png='mms_omni_8hr.png')
# Out:
# 17-May-24 10:31:26: Downloading remote index: https://spdf.gsfc.nasa.gov/pub/data/omni/omni_cdaweb/hro2_1min/2023/
# 17-May-24 10:31:26: File is current: omni_data/hro2_1min/2023/omni_hro2_1min_20230301_v01.cdf

# %% [markdown]
# # Magnetopause crossing events #
#
# ![MAGNETOPAUSE CROSSING](mms_omni_8hr.png)
#
# From 01:00 to 02:00, MMS-1 was in the solar wind.  At 02:00 it encounters the bow shock and enters the magnetosheath.  Around 03:00 we can see the solar wind proton density start to increase, with the flow speed remaining steady at about 440 km/sec, which increases the dynamic pressure.
#
# As shown in the "MMS, THEMIS, Arase orbits" notebook, higher dynamic pressure causes the magnetopause to move inward -- in this case, pushing it inward enough so that MMS-1 finds itself back in the solar wind between 03:15 and 04:20.  The solar wind density and pressure start decreasing around 3:45, and around 04:30 MMS-1 encounters the bow shock for a second time.  A small increasse in the pressure is visible at around 04:15, and MMS-1 is briefly back in the solar wind around 04:40 - 04:50, when it crosses the bow shock for a third time.
#
# From 04:40 - 07:10, MMS-1 is in the magnetosheath.  Near the end of this period, the magnetic field changes direction, and fast ion flows are encountered and also change direction -- this is the signature of a magnetic reconnection event.
#
# From about 7:10 on, MMS-1 is fully within the magnetosphere. Bz has turned from negative in the solar wind, to positive in Earth's magnetic field, and the particle density is lower than previously seen in the solar wind and magnetosheath.
