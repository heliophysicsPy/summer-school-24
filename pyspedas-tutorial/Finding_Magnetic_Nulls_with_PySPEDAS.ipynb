# %% [markdown]
# ## Finding Magnetic Nulls in MMS and Cluster Data
#
# This notebook will show how to use PySPEDAS to locate and characterize magnetic null points, using data from missions such as MMS or Cluster, which can take simultaneous magnetic field measurements at four or more points in space in a roughly tetrahedral arrangement.   The method used is First Order Taylor Expansion (FOTE), which takes four point field measurements and positions, and uses a tetrahedral interpolation method to estimate the field vector and field gradients at the barycenter of the tetrahedron.  This makes it possible to solve for the position of a magnetic null point, as long as the field measurements vary between the four spacecraft.

# %% [markdown]
# Let's start with a Cluster example from August 17, 2003.  This event is used as an example in Fu et al [2015], available online here:
#
# https://agupubs.onlinelibrary.wiley.com/doi/10.1002/2015JA021082
#
# We will need to load magnetic field measurements and ephemeris positions from all four probes.  Both data sets can be found in the 'CP_FGM_FULL' datatype.  We will load the data directly from the Cluster Science Archive, using the load routine `pyspedas.cluster.load_csa()`

# %%
# Here are some imports we'll need below.
import pyspedas
import pytplot

# We'll import a few pytplot routines, to simplify things below
from pytplot import timespan, highlight, time_double, options, tplot, tnames

# %%
data = pyspedas.cluster.load_csa(probes=['C1','C2','C3','C4'],trange=['2003-08-17/16:40', '2003-08-17/16:45'],datatypes='CP_FGM_FULL', time_clip=True)
pytplot.tplot_names()
# Out:
# 07-May-24 15:08:28: Downloading Cluster data, please wait....
# 07-May-24 15:09:04: Download complete.
# 0 : B_vec_xyz_gse__C1_CP_FGM_FULL
# 1 : B_mag__C1_CP_FGM_FULL
# 2 : sc_pos_xyz_gse__C1_CP_FGM_FULL
# 3 : B_vec_xyz_gse__C2_CP_FGM_FULL
# 4 : B_mag__C2_CP_FGM_FULL
# 5 : sc_pos_xyz_gse__C2_CP_FGM_FULL
# 6 : B_vec_xyz_gse__C3_CP_FGM_FULL
# 7 : B_mag__C3_CP_FGM_FULL
# 8 : sc_pos_xyz_gse__C3_CP_FGM_FULL
# 9 : B_vec_xyz_gse__C4_CP_FGM_FULL
# 10 : B_mag__C4_CP_FGM_FULL
# 11 : sc_pos_xyz_gse__C4_CP_FGM_FULL
# ['B_vec_xyz_gse__C1_CP_FGM_FULL',
#  'B_mag__C1_CP_FGM_FULL',
#  'sc_pos_xyz_gse__C1_CP_FGM_FULL',
#  'B_vec_xyz_gse__C2_CP_FGM_FULL',
#  'B_mag__C2_CP_FGM_FULL',
#  'sc_pos_xyz_gse__C2_CP_FGM_FULL',
#  'B_vec_xyz_gse__C3_CP_FGM_FULL',
#  'B_mag__C3_CP_FGM_FULL',
#  'sc_pos_xyz_gse__C3_CP_FGM_FULL',
#  'B_vec_xyz_gse__C4_CP_FGM_FULL',
#  'B_mag__C4_CP_FGM_FULL',
#  'sc_pos_xyz_gse__C4_CP_FGM_FULL']

# %% [markdown]
# Now we set up two lists of tplot variables, representing the field measurements and spacecraft positions.

# %%
fields = ['B_vec_xyz_gse__C'+prb+'_CP_FGM_FULL' for prb in ['1', '2', '3', '4']]
positions = ['sc_pos_xyz_gse__C'+prb+'_CP_FGM_FULL' for prb in ['1', '2', '3', '4']]

print(fields)
print(positions)
# Out:
# ['B_vec_xyz_gse__C1_CP_FGM_FULL', 'B_vec_xyz_gse__C2_CP_FGM_FULL', 'B_vec_xyz_gse__C3_CP_FGM_FULL', 'B_vec_xyz_gse__C4_CP_FGM_FULL']
# ['sc_pos_xyz_gse__C1_CP_FGM_FULL', 'sc_pos_xyz_gse__C2_CP_FGM_FULL', 'sc_pos_xyz_gse__C3_CP_FGM_FULL', 'sc_pos_xyz_gse__C4_CP_FGM_FULL']

# %% [markdown]
# Fu's paper used GSM coordinates.  We will use pyspedas.cotrans() on the field and position variables to do the conversion:

# %%
for f in fields:
    pyspedas.cotrans(f,coord_out='gsm')
for p in positions:
    pyspedas.cotrans(p,coord_out='gsm')
fields_gsm = tnames('B_vec_xyz_gse*gsm')
positions_gsm = tnames('sc_pos_xyz*gsm')
# Out:
# 07-May-24 15:09:04: ['gse', 'gsm']
# 07-May-24 15:09:04: Running transformation: subgse2gsm
# 07-May-24 15:09:04: Output variable: B_vec_xyz_gse__C1_CP_FGM_FULL_gsm
# 07-May-24 15:09:04: ['gse', 'gsm']
# 07-May-24 15:09:05: Running transformation: subgse2gsm
# 07-May-24 15:09:05: Output variable: B_vec_xyz_gse__C2_CP_FGM_FULL_gsm
# 07-May-24 15:09:05: ['gse', 'gsm']
# 07-May-24 15:09:05: Running transformation: subgse2gsm
# 07-May-24 15:09:05: Output variable: B_vec_xyz_gse__C3_CP_FGM_FULL_gsm
# 07-May-24 15:09:05: ['gse', 'gsm']
# 07-May-24 15:09:05: Running transformation: subgse2gsm
# 07-May-24 15:09:05: Output variable: B_vec_xyz_gse__C4_CP_FGM_FULL_gsm
# 07-May-24 15:09:05: ['gse', 'gsm']
# 07-May-24 15:09:05: Running transformation: subgse2gsm
# 07-May-24 15:09:05: Output variable: sc_pos_xyz_gse__C1_CP_FGM_FULL_gsm
# 07-May-24 15:09:05: ['gse', 'gsm']
# 07-May-24 15:09:05: Running transformation: subgse2gsm
# 07-May-24 15:09:05: Output variable: sc_pos_xyz_gse__C2_CP_FGM_FULL_gsm
# 07-May-24 15:09:05: ['gse', 'gsm']
# 07-May-24 15:09:05: Running transformation: subgse2gsm
# 07-May-24 15:09:05: Output variable: sc_pos_xyz_gse__C3_CP_FGM_FULL_gsm
# 07-May-24 15:09:05: ['gse', 'gsm']
# 07-May-24 15:09:05: Running transformation: subgse2gsm
# 07-May-24 15:09:05: Output variable: sc_pos_xyz_gse__C4_CP_FGM_FULL_gsm

# %% [markdown]
# Let's take a look at the magnetometer data from all four probes.

# %%
tplot(fields_gsm)

# %% [markdown]
# The time interval around 16:42 looks interesting -- all four probes are seeing field measurements near zero, with some sign changes, so there might be a magnetic null in or near the tetrahedron.
#
# Now we call the FOTE magnetic null finder. In addition to the two sets of tplot variables, it takes some smoothing parameters to apply to the field data.  In this call, we will disable smoothing. The output will be a list of tplot variables describing the nulls found.

# %%
null_vars = pyspedas.find_magnetic_nulls_fote(fields=fields_gsm, positions=positions_gsm, smooth_fields=False)
print(null_vars)
# Out:
# 07-May-24 15:09:06: tinterpol (linear) was applied to: pos1_i
# 07-May-24 15:09:06: tinterpol (linear) was applied to: pos2_i
# 07-May-24 15:09:06: tinterpol (linear) was applied to: pos3_i
# 07-May-24 15:09:06: tinterpol (linear) was applied to: pos4_i
# 07-May-24 15:09:06: tinterpol (linear) was applied to: b1_i
# 07-May-24 15:09:06: tinterpol (linear) was applied to: b2_i
# 07-May-24 15:09:06: tinterpol (linear) was applied to: b3_i
# 07-May-24 15:09:06: tinterpol (linear) was applied to: b4_i
# 07-May-24 15:09:07: Calculations completed
# ['null_pos', 'null_bary_dist', 'null_bary_dist_types', 'null_sc_distances', 'null_fom', 'null_typecode', 'max_reconstruction_error']

# %% [markdown]
# We see that several tplot variables were produced:
#
# * null_pos: Contains the position of any nulls found, in the same coordinate system as the s/c positions
# * null_bary_dist:  Euclidean distance between the nulls and the tetrahedron barycenter
# * null_bary_dist_types:  Null-barycenter distances, annotated with the topological type of any nulls found (X-type, O-type, A-type (radial), B-type (radial), A_s type (spiral), or B_s type (spiral).
# * null_sc_distances:  Euclidean distance between the null, and each of the four spacecraft
# * null_fom:  The "eta" and "xi" figures of merit, representing the confidence in the null location and null type detection.  Lower is better, with < 0.4 denoting fairly believable results
# * null_typecode:  An integer representing the type of the nulls found
# * max_reconstruction_error:  The maximum difference, among the four s/c, of the difference between the observed field vectors, and field vectors reconstructed from the interpolated values and estimated gradients.  These should be very close to zero.
#
# Let's plot a few of these quantities.

# %%
tplot(['null_bary_dist_types','null_fom','max_reconstruction_error'])

# %% [markdown]
# The reconstruction error is down around 2e-14, close to the double precision floating point resolution, as expected. Let's take a closer look at a two-second time interval, 16:41:55 to 16:41:57.  We'll also reduce the yrange of the null_fom plot to be a little easier to interpret.

# %%
options('null_fom','yrange',[0.0,0.4])
timespan('2003-08-17/16:41:55.0',2.0,'seconds')
tplot(['null_sc_distances','null_bary_dist_types','null_fom'])
# Out:
# 07-May-24 15:09:09: No data found in the time range: null_type5
# 07-May-24 15:09:09: No data found in the time range: null_type9

# %% [markdown]
# It appears that a null passed very near or within the Cluster tetrahedron around 16:41:55.6.   Initially, it was classified (using the three complex eigenvalues of the estimated Jacobian matrix) as a B-type radial null, as shown in the second panel.  The type then appears to switch to B_s type (spiral), then simplify to a 2-D X-type null.  However, the xi values have risen above 0.4 when the null type classification changes, so the B_s and X classifications may be artifacts.

# %% [markdown]
# Now let's look at another example, using MMS data.  This event, on 2017-07-26, is studied in Zhang et al [2023], available online here:
#
# https://iopscience.iop.org/article/10.3847/1538-4357/acdacf
#
# We'll start by loading some relevant data: ephemeris data for the probe positions, FGM data for the magnetic field measurements, and FPI data for particle moments and energy spectra.

# %%
state_vars = pyspedas.mms.mms_load_state(trange=['2017-07-26/07:00','2017-07-26/08:00'],probe=['1','2','3','4'])

# For FGM, we'll use the survey data for the overview plot, and burst data for the
# null analysis.

fgm_vars = pyspedas.mms.fgm(trange=['2017-07-26/07:00','2017-07-26/08:00'],probe=['1','2','3','4'],data_rate='brst',time_clip=True)
fgm_vars = pyspedas.mms.fgm(trange=['2017-07-26/07:00','2017-07-26/08:00'],probe=['1'],data_rate='srvy',time_clip=True)

fpi_vars = pyspedas.mms.mms_load_fpi(trange=['2017-07-26/07:00','2017-07-26/08:00'],probe=['1','2','3','4'],time_clip=True,data_rate='fast')

# Reset time limits from previous examples
timespan('2017-07-26/08:00',60.0,'minutes')
# Out:
# 07-May-24 15:09:11: Downloading MMS1_DEFEPH_2017207_2017208.V01 to pydata/ancillary/mms1/defeph
# 07-May-24 15:09:12: Downloading MMS1_DEFEPH_2017206_2017207.V01 to pydata/ancillary/mms1/defeph
# 07-May-24 15:09:13: Loading pydata/ancillary/mms1/defeph/MMS1_DEFEPH_2017206_2017207.V01
# 07-May-24 15:09:13: Loading pydata/ancillary/mms1/defeph/MMS1_DEFEPH_2017207_2017208.V01
# 07-May-24 15:09:13: Downloading MMS2_DEFEPH_2017207_2017208.V01 to pydata/ancillary/mms2/defeph
# 07-May-24 15:09:14: Downloading MMS2_DEFEPH_2017206_2017207.V01 to pydata/ancillary/mms2/defeph
# 07-May-24 15:09:15: Loading pydata/ancillary/mms2/defeph/MMS2_DEFEPH_2017206_2017207.V01
# 07-May-24 15:09:15: Loading pydata/ancillary/mms2/defeph/MMS2_DEFEPH_2017207_2017208.V01
# 07-May-24 15:09:16: Downloading MMS3_DEFEPH_2017207_2017208.V01 to pydata/ancillary/mms3/defeph
# 07-May-24 15:09:17: Downloading MMS3_DEFEPH_2017206_2017207.V01 to pydata/ancillary/mms3/defeph
# 07-May-24 15:09:17: Loading pydata/ancillary/mms3/defeph/MMS3_DEFEPH_2017206_2017207.V01
# 07-May-24 15:09:18: Loading pydata/ancillary/mms3/defeph/MMS3_DEFEPH_2017207_2017208.V01
# 07-May-24 15:09:18: Downloading MMS4_DEFEPH_2017207_2017208.V01 to pydata/ancillary/mms4/defeph
# 07-May-24 15:09:19: Downloading MMS4_DEFEPH_2017206_2017207.V01 to pydata/ancillary/mms4/defeph
# 07-May-24 15:09:20: Loading pydata/ancillary/mms4/defeph/MMS4_DEFEPH_2017206_2017207.V01
# 07-May-24 15:09:20: Loading pydata/ancillary/mms4/defeph/MMS4_DEFEPH_2017207_2017208.V01
# 07-May-24 15:09:21: Loaded variables:
# 07-May-24 15:09:21: mms1_defeph_pos
# 07-May-24 15:09:21: mms1_defeph_vel
# 07-May-24 15:09:21: mms2_defeph_pos
# 07-May-24 15:09:21: mms2_defeph_vel
# 07-May-24 15:09:21: mms3_defeph_pos
# 07-May-24 15:09:21: mms3_defeph_vel
# 07-May-24 15:09:21: mms4_defeph_pos
# 07-May-24 15:09:21: mms4_defeph_vel
# 07-May-24 15:09:23: Downloading mms1_fgm_brst_l2_20170726065803_v5.98.0.cdf to pydata/mms1/fgm/brst/l2/2017/07/26
# 07-May-24 15:09:25: Downloading mms1_fgm_brst_l2_20170726070303_v5.98.0.cdf to pydata/mms1/fgm/brst/l2/2017/07/26
fast is currently not in pytplot
# 07-May-24 15:24:45: The name mms4_dis_pitchangdist_miden_fast is currently not in pytplot
# 07-May-24 15:24:45: The name mms4_dis_pitchangdist_highen_fast is currently not in pytplot
# 07-May-24 15:24:45: Loaded variables:
# 07-May-24 15:24:45: Epoch
# 07-May-24 15:24:45: Epoch_plus_var
# 07-May-24 15:24:45: Epoch_minus_var
# 07-May-24 15:24:45: mms1_des_errorflags_fast
# 07-May-24 15:24:45: mms1_des_compressionloss_fast
# 07-May-24 15:24:45: mms1_des_startdelphi_count_fast
# 07-May-24 15:24:45: mms1_des_startdelphi_angle_fast
# 07-May-24 15:24:45: mms1_des_dist_fast
# 07-May-24 15:24:45: mms1_des_disterr_fast
# 07-May-24 15:24:45: mms1_des_avgf1counts_fast
# 07-May-24 15:24:45: mms1_des_theta_fast
# 07-May-24 15:24:45: mms1_des_theta_delta_fast
# 07-May-24 15:24:45: mms1_des_energy_fast
# 07-May-24 15:24:45: mms1_des_energy_delta_fast
# 07-May-24 15:24:45: mms1_des_phi_fast
# 07-May-24 15:24:45: mms1_des_phi_delta_fast
# 07-May-24 15:24:45: mms1_des_pitchangdist_lowen_fast
# 07-May-24 15:24:45: mms1_des_pitchangdist_miden_fast
# 07-May-24 15:24:45: mms1_des_pitchangdist_highen_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_px_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_mx_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_py_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_my_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_pz_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_mz_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_par_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_anti_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_perp_fast
# 07-May-24 15:24:45: mms1_des_energyspectr_omni_fast
# 07-May-24 15:24:45: mms1_des_numberdensity_fast
# 07-May-24 15:24:45: mms1_des_numberdensity_err_fast
# 07-May-24 15:24:45: mms1_des_densityextrapolation_low_fast
# 07-May-24 15:24:45: mms1_des_densityextrapolation_high_fast
# 07-May-24 15:24:45: mms1_des_bulkv_dbcs_fast
# 07-May-24 15:24:45: mms1_des_bulkv_spintone_dbcs_fast
# 07-May-24 15:24:45: mms1_des_bulkv_gse_fast
# 07-May-24 15:24:45: mms1_des_bulkv_spintone_gse_fast
# 07-May-24 15:24:45: mms1_des_bulkv_err_fast
# 07-May-24 15:24:45: mms1_des_prestensor_dbcs_fast
# 07-May-24 15:24:45: mms1_des_prestensor_gse_fast
# 07-May-24 15:24:45: mms1_des_prestensor_err_fast
# 07-May-24 15:24:45: mms1_des_temptensor_dbcs_fast
# 07-May-24 15:24:45: mms1_des_temptensor_gse_fast
# 07-May-24 15:24:45: mms1_des_temptensor_err_fast
# 07-May-24 15:24:45: mms1_des_heatq_dbcs_fast
# 07-May-24 15:24:45: mms1_des_heatq_gse_fast
# 07-May-24 15:24:45: mms1_des_heatq_err_fast
# 07-May-24 15:24:45: mms1_des_alpha_fast
# 07-May-24 15:24:45: mms2_des_startdelphi_angle_fast
# 07-May-24 15:24:45: mms2_des_dist_fast
# 07-May-24 15:24:45: mms2_des_disterr_fast
# 07-May-24 15:24:45: mms2_des_avgf1counts_fast
# 07-May-24 15:24:45: mms2_des_theta_fast
# 07-May-24 15:24:45: mms2_des_theta_delta_fast
# 07-May-24 15:24:45: mms2_des_energy_fast
# 07-May-24 15:24:45: mms2_des_energy_delta_fast
# 07-May-24 15:24:45: mms2_des_phi_fast
# 07-May-24 15:24:45: mms2_des_phi_delta_fast
# 07-May-24 15:24:45: mms2_des_pitchangdist_lowen_fast
# 07-May-24 15:24:45: mms2_des_pitchangdist_miden_fast
# 07-May-24 15:24:45: mms2_des_pitchangdist_highen_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_px_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_mx_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_py_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_my_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_pz_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_mz_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_par_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_anti_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_perp_fast
# 07-May-24 15:24:45: mms2_des_energyspectr_omni_fast
# 07-May-24 15:24:45: mms2_des_numberdensity_fast
# 07-May-24 15:24:45: mms2_des_numberdensity_err_fast
# 07-May-24 15:24:45: mms2_des_densityextrapolation_low_fast
# 07-May-24 15:24:45: mms2_des_densityextrapolation_high_fast
# 07-May-24 15:24:45: mms2_des_bulkv_dbcs_fast
# 07-May-24 15:24:45: mms2_des_bulkv_spintone_dbcs_fast
# 07-May-24 15:24:45: mms2_des_bulkv_gse_fast
# 07-May-24 15:24:45: mms2_des_bulkv_spintone_gse_fast
# 07-May-24 15:24:45: mms2_des_bulkv_err_fast
# 07-May-24 15:24:45: mms2_des_prestensor_dbcs_fast
# 07-May-24 15:24:45: mms2_des_prestensor_gse_fast
# 07-May-24 15:24:45: mms2_des_prestensor_err_fast
# 07-May-24 15:24:45: mms2_des_temptensor_dbcs_fast
# 07-May-24 15:24:45: mms2_des_temptensor_gse_fast
# 07-May-24 15:24:45: mms2_des_temptensor_err_fast
# 07-May-24 15:24:45: mms2_des_heatq_dbcs_fast
# 07-May-24 15:24:45: mms2_des_heatq_gse_fast
# 07-May-24 15:24:45: mms2_des_heatq_err_fast
# 07-May-24 15:24:45: mms2_des_alpha_fast
# 07-May-24 15:24:45: mms2_des_alpha_delta_fast
# 07-May-24 15:24:45: mms2_des_temppara_fast
# 07-May-24 15:24:45: mms2_des_tempperp_fast
# 07-May-24 15:24:45: mms2_dis_errorflags_fast
# 07-May-24 15:24:45: mms2_dis_compressionloss_fast
# 07-May-24 15:24:45: mms2_dis_startdelphi_count_fast
# 07-May-24 15:24:45: mms2_dis_startdelphi_angle_fast
# 07-May-24 15:24:45: mms2_dis_dist_fast
# 07-May-24 15:24:45: mms2_dis_disterr_fast
# 07-May-24 15:24:45: mms2_dis_avgf1counts_fast
# 07-May-24 15:24:45: mms2_dis_theta_fast
# 07-May-24 15:24:45: mms2_dis_theta_delta_fast
# 07-May-24 15:24:45: mms2_dis_energy_fast
# 07-May-24 15:24:45: mms2_dis_energy_delta_fast
# 07-May-24 15:24:45: mms2_dis_phi_fast
# 07-May-24 15:24:45: mms2_dis_phi_delta_fast
# 07-May-24 15:24:45: mms2_dis_energyspectr_px_fast
# 07-May-24 15:24:45: mms2_dis_energyspectr_mx_fast
# 07-May-24 15:24:45: mms2_dis_energyspectr_py_fast
# 07-May-24 15:24:45: mms2_dis_energyspectr_my_fast
# 07-May-24 15:24:45: mms2_dis_energyspectr_pz_fast
# 07-May-24 15:24:45: mms2_dis_energyspectr_mz_fast
# 07-May-24 15:24:45: mms2_dis_energyspectr_omni_fast
# 07-May-24 15:24:45: mms2_dis_spectr_bg_fast
# 07-May-24 15:24:45: mms2_dis_numberdensity_bg_fast
# 07-May-24 15:24:45: mms2_dis_numberdensity_fast
# 07-May-24 15:24:45: mms2_dis_numberdensity_err_fast
# 07-May-24 15:24:45: mms2_dis_densityextrapolation_low_fast
# 07-May-24 15:24:45: mms2_dis_densityextrapolation_high_fast
# 07-May-24 15:24:45: mms2_dis_bulkv_dbcs_fast
# 07-May-24 15:24:45: mms2_dis_bulkv_spintone_dbcs_fast
# 07-May-24 15:24:45: mms2_dis_bulkv_gse_fast
# 07-May-24 15:24:45: mms2_dis_bulkv_spintone_gse_fast
# 07-May-24 15:24:45: mms2_dis_bulkv_err_fast
# 07-May-24 15:24:45: mms2_dis_prestensor_dbcs_fast
# 07-May-24 15:24:45: mms2_dis_prestensor_gse_fast
# 07-May-24 15:24:45: mms2_dis_prestensor_err_fast
# 07-May-24 15:24:45: mms2_dis_pres_bg_fast
# 07-May-24 15:24:45: mms2_dis_temptensor_dbcs_fast
# 07-May-24 15:24:45: mms2_dis_temptensor_gse_fast
# 07-May-24 15:24:45: mms2_dis_temptensor_err_fast
# 07-May-24 15:24:45: mms2_dis_heatq_dbcs_fast
# 07-May-24 15:24:45: mms2_dis_heatq_gse_fast
# 07-May-24 15:24:45: mms2_dis_heatq_err_fast
# 07-May-24 15:24:45: mms2_dis_temppara_fast
# 07-May-24 15:24:45: mms2_dis_tempperp_fast
# 07-May-24 15:24:45: mms3_des_errorflags_fast
# 07-May-24 15:24:45: mms3_des_compressionloss_fast
# 07-May-24 15:24:45: mms3_des_startdelphi_count_fast
# 07-May-24 15:24:45: mms3_des_startdelphi_angle_fast
# 07-May-24 15:24:45: mms3_des_dist_fast
# 07-May-24 15:24:45: mms3_des_disterr_fast
# 07-May-24 15:24:45: mms3_des_avgf1counts_fast
# 07-May-24 15:24:45: mms3_des_theta_fast
# 07-May-24 15:24:45: mms3_des_theta_delta_fast
# 07-May-24 15:24:45: mms3_des_energy_fast
# 07-May-24 15:24:45: mms3_des_energy_delta_fast
# 07-May-24 15:24:45: mms3_des_phi_fast
# 07-May-24 15:24:45: mms3_des_phi_delta_fast
# 07-May-24 15:24:45: mms3_des_pitchangdist_lowen_fast
# 07-May-24 15:24:45: mms3_des_pitchangdist_miden_fast
# 07-May-24 15:24:45: mms3_des_pitchangdist_highen_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_px_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_mx_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_py_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_my_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_pz_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_mz_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_par_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_anti_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_perp_fast
# 07-May-24 15:24:45: mms3_des_energyspectr_omni_fast
# 07-May-24 15:24:45: mms3_des_numberdensity_fast
# 07-May-24 15:24:45: mms3_des_numberdensity_err_fast
# 07-May-24 15:24:45: mms3_des_densityextrapolation_low_fast
# 07-May-24 15:24:45: mms3_des_densityextrapolation_high_fast
# 07-May-24 15:24:45: mms3_des_bulkv_dbcs_fast
# 07-May-24 15:24:45: mms3_des_bulkv_spintone_dbcs_fast
# 07-May-24 15:24:45: mms3_des_bulkv_gse_fast
# 07-May-24 15:24:45: mms3_des_bulkv_spintone_gse_fast
# 07-May-24 15:24:45: mms3_des_bulkv_err_fast
# 07-May-24 15:24:45: mms3_des_prestensor_dbcs_fast
# 07-May-24 15:24:45: mms3_des_prestensor_gse_fast
# 07-May-24 15:24:45: mms3_des_prestensor_err_fast
# 07-May-24 15:24:45: mms3_des_temptensor_dbcs_fast
# 07-May-24 15:24:45: mms3_des_temptensor_gse_fast
# 07-May-24 15:24:45: mms3_des_temptensor_err_fast
# 07-May-24 15:24:45: mms3_des_heatq_dbcs_fast
# 07-May-24 15:24:45: mms3_des_heatq_gse_fast
# 07-May-24 15:24:45: mms3_des_heatq_err_fast
# 07-May-24 15:24:45: mms3_des_alpha_fast
# 07-May-24 15:24:45: mms3_des_alpha_delta_fast
# 07-May-24 15:24:45: mms3_des_temppara_fast
# 07-May-24 15:24:45: mms3_des_tempperp_fast
# 07-May-24 15:24:45: mms3_dis_errorflags_fast
# 07-May-24 15:24:45: mms3_dis_compressionloss_fast
# 07-May-24 15:24:45: mms3_dis_startdelphi_count_fast
# 07-May-24 15:24:45: mms3_dis_startdelphi_angle_fast
# 07-May-24 15:24:45: mms3_dis_dist_fast
# 07-May-24 15:24:45: mms3_dis_disterr_fast
# 07-May-24 15:24:45: mms3_dis_avgf1counts_fast
# 07-May-24 15:24:45: mms3_dis_theta_fast
# 07-May-24 15:24:45: mms3_dis_theta_delta_fast
# 07-May-24 15:24:45: mms3_dis_energy_fast
# 07-May-24 15:24:45: mms3_dis_energy_delta_fast
# 07-May-24 15:24:45: mms3_dis_phi_fast
# 07-May-24 15:24:45: mms3_dis_phi_delta_fast
# 07-May-24 15:24:45: mms3_dis_energyspectr_px_fast
# 07-May-24 15:24:45: mms3_dis_energyspectr_mx_fast
# 07-May-24 15:24:45: mms3_dis_energyspectr_py_fast
# 07-May-24 15:24:45: mms3_dis_energyspectr_my_fast
# 07-May-24 15:24:45: mms3_dis_energyspectr_pz_fast
# 07-May-24 15:24:45: mms3_dis_energyspectr_mz_fast
# 07-May-24 15:24:45: mms3_dis_energyspectr_omni_fast
# 07-May-24 15:24:45: mms3_dis_spectr_bg_fast
# 07-May-24 15:24:45: mms3_dis_numberdensity_bg_fast
# 07-May-24 15:24:45: mms3_dis_numberdensity_fast
# 07-May-24 15:24:45: mms3_dis_numberdensity_err_fast
# 07-May-24 15:24:45: mms3_dis_densityextrapolation_low_fast
# 07-May-24 15:24:45: mms3_dis_densityextrapolation_high_fast
# 07-May-24 15:24:45: mms3_dis_bulkv_dbcs_fast
# 07-May-24 15:24:45: mms3_dis_bulkv_spintone_dbcs_fast
# 07-May-24 15:24:45: mms3_dis_bulkv_gse_fast
# 07-May-24 15:24:45: mms3_dis_bulkv_spintone_gse_fast
# 07-May-24 15:24:45: mms3_dis_bulkv_err_fast
# 07-May-24 15:24:45: mms3_dis_prestensor_dbcs_fast
# 07-May-24 15:24:45: mms3_dis_prestensor_gse_fast
# 07-May-24 15:24:45: mms3_dis_prestensor_err_fast
# 07-May-24 15:24:45: mms3_dis_pres_bg_fast
# 07-May-24 15:24:45: mms3_dis_temptensor_dbcs_fast
# 07-May-24 15:24:45: mms3_dis_temptensor_gse_fast
# 07-May-24 15:24:45: mms3_dis_temptensor_err_fast
# 07-May-24 15:24:45: mms3_dis_heatq_dbcs_fast
# 07-May-24 15:24:45: mms3_dis_heatq_gse_fast
# 07-May-24 15:24:45: mms3_dis_heatq_err_fast
# 07-May-24 15:24:45: mms3_dis_temppara_fast
# 07-May-24 15:24:45: mms3_dis_tempperp_fast
# 07-May-24 15:24:45: mms4_des_errorflags_fast
# 07-May-24 15:24:45: mms4_des_compressionloss_fast
# 07-May-24 15:24:45: mms4_des_startdelphi_count_fast
# 07-May-24 15:24:45: mms4_des_startdelphi_angle_fast
# 07-May-24 15:24:45: mms4_des_dist_fast
# 07-May-24 15:24:45: mms4_des_disterr_fast
# 07-May-24 15:24:45: mms4_des_avgf1counts_fast
# 07-May-24 15:24:45: mms4_des_theta_fast
# 07-May-24 15:24:45: mms4_des_theta_delta_fast
# 07-May-24 15:24:45: mms4_des_energy_fast
# 07-May-24 15:24:45: mms4_des_energy_delta_fast
# 07-May-24 15:24:45: mms4_des_phi_fast
# 07-May-24 15:24:45: mms4_des_phi_delta_fast
# 07-May-24 15:24:45: mms4_des_pitchangdist_lowen_fast
# 07-May-24 15:24:45: mms4_des_pitchangdist_miden_fast
# 07-May-24 15:24:45: mms4_des_pitchangdist_highen_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_px_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_mx_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_py_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_my_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_pz_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_mz_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_par_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_anti_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_perp_fast
# 07-May-24 15:24:45: mms4_des_energyspectr_omni_fast
# 07-May-24 15:24:45: mms4_des_numberdensity_fast
# 07-May-24 15:24:45: mms4_des_numberdensity_err_fast
# 07-May-24 15:24:45: mms4_des_densityextrapolation_low_fast
# 07-May-24 15:24:45: mms4_des_densityextrapolation_high_fast
# 07-May-24 15:24:45: mms4_des_bulkv_dbcs_fast
# 07-May-24 15:24:45: mms4_des_bulkv_spintone_dbcs_fast
# 07-May-24 15:24:45: mms4_des_bulkv_gse_fast
# 07-May-24 15:24:45: mms4_des_bulkv_spintone_gse_fast
# 07-May-24 15:24:45: mms4_des_bulkv_err_fast
# 07-May-24 15:24:45: mms4_des_prestensor_dbcs_fast
# 07-May-24 15:24:45: mms4_des_prestensor_gse_fast
# 07-May-24 15:24:45: mms4_des_prestensor_err_fast
# 07-May-24 15:24:45: mms4_des_temptensor_dbcs_fast
# 07-May-24 15:24:45: mms4_des_temptensor_gse_fast
# 07-May-24 15:24:45: mms4_des_temptensor_err_fast
# 07-May-24 15:24:45: mms4_des_heatq_dbcs_fast
# 07-May-24 15:24:45: mms4_des_heatq_gse_fast
# 07-May-24 15:24:45: mms4_des_heatq_err_fast
# 07-May-24 15:24:45: mms4_des_alpha_fast
# 07-May-24 15:24:45: mms4_des_alpha_delta_fast
# 07-May-24 15:24:45: mms4_des_temppara_fast
# 07-May-24 15:24:45: mms4_des_tempperp_fast
# 07-May-24 15:24:45: mms4_dis_errorflags_fast
# 07-May-24 15:24:45: mms4_dis_compressionloss_fast
# 07-May-24 15:24:45: mms4_dis_startdelphi_count_fast
# 07-May-24 15:24:45: mms4_dis_startdelphi_angle_fast
# 07-May-24 15:24:45: mms4_dis_dist_fast
# 07-May-24 15:24:45: mms4_dis_disterr_fast
# 07-May-24 15:24:45: mms4_dis_avgf1counts_fast
# 07-May-24 15:24:45: mms4_dis_theta_fast
# 07-May-24 15:24:45: mms4_dis_theta_delta_fast
# 07-May-24 15:24:45: mms4_dis_energy_fast
# 07-May-24 15:24:45: mms4_dis_energy_delta_fast
# 07-May-24 15:24:45: mms4_dis_phi_fast
# 07-May-24 15:24:45: mms4_dis_phi_delta_fast
# 07-May-24 15:24:45: mms4_dis_energyspectr_px_fast
# 07-May-24 15:24:45: mms4_dis_energyspectr_mx_fast
# 07-May-24 15:24:45: mms4_dis_energyspectr_py_fast
# 07-May-24 15:24:45: mms4_dis_energyspectr_my_fast
# 07-May-24 15:24:45: mms4_dis_energyspectr_pz_fast
# 07-May-24 15:24:45: mms4_dis_energyspectr_mz_fast
# 07-May-24 15:24:45: mms4_dis_energyspectr_omni_fast
# 07-May-24 15:24:45: mms4_dis_spectr_bg_fast
# 07-May-24 15:24:45: mms4_dis_numberdensity_bg_fast
# 07-May-24 15:24:45: mms4_dis_numberdensity_fast
# 07-May-24 15:24:45: mms4_dis_numberdensity_err_fast
# 07-May-24 15:24:45: mms4_dis_densityextrapolation_low_fast
# 07-May-24 15:24:45: mms4_dis_densityextrapolation_high_fast
# 07-May-24 15:24:45: mms4_dis_bulkv_dbcs_fast
# 07-May-24 15:24:45: mms4_dis_bulkv_spintone_dbcs_fast
# 07-May-24 15:24:45: mms4_dis_bulkv_gse_fast
# 07-May-24 15:24:45: mms4_dis_bulkv_spintone_gse_fast
# 07-May-24 15:24:45: mms4_dis_bulkv_err_fast
# 07-May-24 15:24:45: mms4_dis_prestensor_dbcs_fast
# 07-May-24 15:24:45: mms4_dis_prestensor_gse_fast
# 07-May-24 15:24:45: mms4_dis_prestensor_err_fast
# 07-May-24 15:24:45: mms4_dis_pres_bg_fast
# 07-May-24 15:24:45: mms4_dis_temptensor_dbcs_fast
# 07-May-24 15:24:45: mms4_dis_temptensor_gse_fast
# 07-May-24 15:24:45: mms4_dis_temptensor_err_fast
# 07-May-24 15:24:45: mms4_dis_heatq_dbcs_fast
# 07-May-24 15:24:45: mms4_dis_heatq_gse_fast
# 07-May-24 15:24:45: mms4_dis_heatq_err_fast
# 07-May-24 15:24:45: mms4_dis_temppara_fast
# 07-May-24 15:24:45: mms4_dis_tempperp_fast
# 07-May-24 15:24:45: mms1_des_errorflags_fast_moms
# 07-May-24 15:24:45: mms1_des_compressionloss_fast_moms
# 07-May-24 15:24:45: mms2_des_errorflags_fast_moms
# 07-May-24 15:24:45: mms2_des_compressionloss_fast_moms
# 07-May-24 15:24:45: mms3_des_errorflags_fast_moms
# 07-May-24 15:24:45: mms3_des_compressionloss_fast_moms
# 07-May-24 15:24:45: mms4_des_errorflags_fast_moms
# 07-May-24 15:24:45: mms4_des_compressionloss_fast_moms
# 07-May-24 15:24:45: mms1_des_errorflags_fast_dist
# 07-May-24 15:24:45: mms1_des_compressionloss_fast_dist
# 07-May-24 15:24:45: mms2_des_errorflags_fast_dist
# 07-May-24 15:24:45: mms2_des_compressionloss_fast_dist
# 07-May-24 15:24:45: mms3_des_errorflags_fast_dist
# 07-May-24 15:24:45: mms3_des_compressionloss_fast_dist
# 07-May-24 15:24:45: mms4_des_errorflags_fast_dist
# 07-May-24 15:24:45: mms4_des_compressionloss_fast_dist
# 07-May-24 15:24:45: mms1_dis_errorflags_fast_moms
# 07-May-24 15:24:45: mms1_dis_compressionloss_fast_moms
# 07-May-24 15:24:45: mms2_dis_errorflags_fast_moms
# 07-May-24 15:24:45: mms2_dis_compressionloss_fast_moms
# 07-May-24 15:24:45: mms3_dis_errorflags_fast_moms
# 07-May-24 15:24:45: mms3_dis_compressionloss_fast_moms
# 07-May-24 15:24:45: mms4_dis_errorflags_fast_moms
# 07-May-24 15:24:45: mms4_dis_compressionloss_fast_moms
# 07-May-24 15:24:45: mms1_dis_errorflags_fast_dist
# 07-May-24 15:24:45: mms1_dis_compressionloss_fast_dist
# 07-May-24 15:24:45: mms2_dis_errorflags_fast_dist
# 07-May-24 15:24:45: mms2_dis_compressionloss_fast_dist
# 07-May-24 15:24:45: mms3_dis_errorflags_fast_dist
# 07-May-24 15:24:45: mms3_dis_compressionloss_fast_dist
# 07-May-24 15:24:45: mms4_dis_errorflags_fast_dist
# 07-May-24 15:24:45: mms4_dis_compressionloss_fast_dist
# 07-May-24 15:24:45: mms1_des_pitchangdist_avg
# 07-May-24 15:24:45: mms1_des_errorflags_fast_dist_flagbars_dist
# 07-May-24 15:24:45: mms1_dis_errorflags_fast_dist_flagbars_dist
# 07-May-24 15:24:45: mms1_dis_errorflags_fast_moms_flagbars_full
# 07-May-24 15:24:45: mms1_dis_errorflags_fast_moms_flagbars_main
# 07-May-24 15:24:45: mms1_dis_errorflags_fast_moms_flagbars_others
# 07-May-24 15:24:45: mms1_dis_errorflags_fast_moms_flagbars_mini
# 07-May-24 15:24:45: mms1_des_pitchangdist_avg
# 07-May-24 15:24:45: mms1_des_errorflags_fast_moms_flagbars_full
# 07-May-24 15:24:45: mms1_des_errorflags_fast_moms_flagbars_main
# 07-May-24 15:24:45: mms1_des_errorflags_fast_moms_flagbars_others
# 07-May-24 15:24:45: mms1_des_errorflags_fast_moms_flagbars_mini
# 07-May-24 15:24:45: mms2_des_pitchangdist_avg
# 07-May-24 15:24:45: mms2_des_errorflags_fast_dist_flagbars_dist
# 07-May-24 15:24:45: mms2_dis_errorflags_fast_dist_flagbars_dist
# 07-May-24 15:24:45: mms2_dis_errorflags_fast_moms_flagbars_full
# 07-May-24 15:24:45: mms2_dis_errorflags_fast_moms_flagbars_main
# 07-May-24 15:24:45: mms2_dis_errorflags_fast_moms_flagbars_others
# 07-May-24 15:24:45: mms2_dis_errorflags_fast_moms_flagbars_mini
# 07-May-24 15:24:45: mms2_des_pitchangdist_avg
# 07-May-24 15:24:45: mms2_des_errorflags_fast_moms_flagbars_full
# 07-May-24 15:24:45: mms2_des_errorflags_fast_moms_flagbars_main
# 07-May-24 15:24:45: mms2_des_errorflags_fast_moms_flagbars_others
# 07-May-24 15:24:45: mms2_des_errorflags_fast_moms_flagbars_mini
# 07-May-24 15:24:45: mms3_des_pitchangdist_avg
# 07-May-24 15:24:45: mms3_des_errorflags_fast_dist_flagbars_dist
# 07-May-24 15:24:45: mms3_dis_errorflags_fast_dist_flagbars_dist
# 07-May-24 15:24:45: mms3_dis_errorflags_fast_moms_flagbars_full
# 07-May-24 15:24:45: mms3_dis_errorflags_fast_moms_flagbars_main
# 07-May-24 15:24:45: mms3_dis_errorflags_fast_moms_flagbars_others
# 07-May-24 15:24:45: mms3_dis_errorflags_fast_moms_flagbars_mini
# 07-May-24 15:24:45: mms3_des_pitchangdist_avg
# 07-May-24 15:24:45: mms3_des_errorflags_fast_moms_flagbars_full
# 07-May-24 15:24:45: mms3_des_errorflags_fast_moms_flagbars_main
# 07-May-24 15:24:45: mms3_des_errorflags_fast_moms_flagbars_others
# 07-May-24 15:24:45: mms3_des_errorflags_fast_moms_flagbars_mini
# 07-May-24 15:24:45: mms4_des_pitchangdist_avg
# 07-May-24 15:24:45: mms4_des_errorflags_fast_dist_flagbars_dist
# 07-May-24 15:24:45: mms4_dis_errorflags_fast_dist_flagbars_dist
# 07-May-24 15:24:45: mms4_dis_errorflags_fast_moms_flagbars_full
# 07-May-24 15:24:45: mms4_dis_errorflags_fast_moms_flagbars_main
# 07-May-24 15:24:45: mms4_dis_errorflags_fast_moms_flagbars_others
# 07-May-24 15:24:45: mms4_dis_errorflags_fast_moms_flagbars_mini
# 07-May-24 15:24:45: mms4_des_pitchangdist_avg
# 07-May-24 15:24:45: mms4_des_errorflags_fast_moms_flagbars_full
# 07-May-24 15:24:45: mms4_des_errorflags_fast_moms_flagbars_main
# 07-May-24 15:24:45: mms4_des_errorflags_fast_moms_flagbars_others
# 07-May-24 15:24:45: mms4_des_errorflags_fast_moms_flagbars_mini

# %% [markdown]
# The MMS ephemeris data is in ECI coordinates.  We'll be working in GSE, so we need to transform the loaded variables.

# %%
# To use the MMS qcotrans routine, the quaternions representing the transforms must be
# loaded from the MEC dataset.
pyspedas.mms.mec(trange=['2017-07-26/07:00','2017-07-26/08:00'], probe=['1','2','3','4'])

for i in ('1','2','3','4'): pyspedas.mms.mms_qcotrans('mms'+i+'_defeph_pos','mms'+i+'_defeph_pos_gse',in_coord='eci',out_coord='gse')
# Out:
# 07-May-24 15:24:47: Downloading mms1_mec_srvy_l2_epht89q_20170726_v2.0.1.cdf to pydata/mms1/mec/srvy/l2/epht89q/2017/07
# 07-May-24 15:24:50: Downloading mms2_mec_srvy_l2_epht89q_20170726_v2.0.1.cdf to pydata/mms2/mec/srvy/l2/epht89q/2017/07
# 07-May-24 15:24:52: Downloading mms3_mec_srvy_l2_epht89q_20170726_v2.0.1.cdf to pydata/mms3/mec/srvy/l2/epht89q/2017/07
# 07-May-24 15:24:55: Downloading mms4_mec_srvy_l2_epht89q_20170726_v2.0.1.cdf to pydata/mms4/mec/srvy/l2/epht89q/2017/07
# 07-May-24 15:25:12: Loaded variables:
# 07-May-24 15:25:12: mms1_mec_dipole_tilt
# 07-May-24 15:25:12: mms1_mec_gmst
# 07-May-24 15:25:12: mms1_mec_mlat
# 07-May-24 15:25:12: mms1_mec_mlt
# 07-May-24 15:25:12: mms1_mec_l_dipole
# 07-May-24 15:25:12: mms1_mec_quat_eci_to_bcs
# 07-May-24 15:25:12: mms1_mec_quat_eci_to_dbcs
# 07-May-24 15:25:12: mms1_mec_quat_eci_to_dmpa
# 07-May-24 15:25:12: mms1_mec_quat_eci_to_smpa
# 07-May-24 15:25:12: mms1_mec_quat_eci_to_dsl
# 07-May-24 15:25:12: mms1_mec_quat_eci_to_ssl
# 07-May-24 15:25:12: mms1_mec_L_vec
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_dmpa
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_smpa
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_dsl
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_ssl
# 07-May-24 15:25:12: mms3_mec_L_vec
# 07-May-24 15:25:12: mms3_mec_Z_vec
# 07-May-24 15:25:12: mms3_mec_P_vec
# 07-May-24 15:25:12: mms3_mec_L_phase
# 07-May-24 15:25:12: mms3_mec_Z_phase
# 07-May-24 15:25:12: mms3_mec_P_phase
# 07-May-24 15:25:12: mms3_mec_kp
# 07-May-24 15:25:12: mms3_mec_dst
# 07-May-24 15:25:12: mms3_mec_earth_eclipse_flag
# 07-May-24 15:25:12: mms3_mec_moon_eclipse_flag
# 07-May-24 15:25:12: mms3_mec_r_eci
# 07-May-24 15:25:12: mms3_mec_v_eci
# 07-May-24 15:25:12: mms3_mec_r_gsm
# 07-May-24 15:25:12: mms3_mec_v_gsm
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_gsm
# 07-May-24 15:25:12: mms3_mec_r_geo
# 07-May-24 15:25:12: mms3_mec_v_geo
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_geo
# 07-May-24 15:25:12: mms3_mec_r_sm
# 07-May-24 15:25:12: mms3_mec_v_sm
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_sm
# 07-May-24 15:25:12: mms3_mec_r_gse
# 07-May-24 15:25:12: mms3_mec_v_gse
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_gse
# 07-May-24 15:25:12: mms3_mec_r_gse2000
# 07-May-24 15:25:12: mms3_mec_v_gse2000
# 07-May-24 15:25:12: mms3_mec_quat_eci_to_gse2000
# 07-May-24 15:25:12: mms3_mec_geod_lat
# 07-May-24 15:25:12: mms3_mec_geod_lon
# 07-May-24 15:25:12: mms3_mec_geod_height
# 07-May-24 15:25:12: mms3_mec_r_sun_de421_eci
# 07-May-24 15:25:12: mms3_mec_r_moon_de421_eci
# 07-May-24 15:25:12: mms3_mec_fieldline_type
# 07-May-24 15:25:12: mms3_mec_bsc_gsm
# 07-May-24 15:25:12: mms3_mec_loss_cone_angle_s
# 07-May-24 15:25:12: mms3_mec_loss_cone_angle_n
# 07-May-24 15:25:12: mms3_mec_pfs_geod_latlon
# 07-May-24 15:25:12: mms3_mec_pfn_geod_latlon
# 07-May-24 15:25:12: mms3_mec_pfs_gsm
# 07-May-24 15:25:12: mms3_mec_bfs_gsm
# 07-May-24 15:25:12: mms3_mec_pfn_gsm
# 07-May-24 15:25:12: mms3_mec_bfn_gsm
# 07-May-24 15:25:12: mms3_mec_pmin_gsm
# 07-May-24 15:25:12: mms3_mec_bmin_gsm
# 07-May-24 15:25:12: mms4_mec_dipole_tilt
# 07-May-24 15:25:12: mms4_mec_gmst
# 07-May-24 15:25:12: mms4_mec_mlat
# 07-May-24 15:25:12: mms4_mec_mlt
# 07-May-24 15:25:12: mms4_mec_l_dipole
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_bcs
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_dbcs
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_dmpa
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_smpa
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_dsl
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_ssl
# 07-May-24 15:25:12: mms4_mec_L_vec
# 07-May-24 15:25:12: mms4_mec_Z_vec
# 07-May-24 15:25:12: mms4_mec_P_vec
# 07-May-24 15:25:12: mms4_mec_L_phase
# 07-May-24 15:25:12: mms4_mec_Z_phase
# 07-May-24 15:25:12: mms4_mec_P_phase
# 07-May-24 15:25:12: mms4_mec_kp
# 07-May-24 15:25:12: mms4_mec_dst
# 07-May-24 15:25:12: mms4_mec_earth_eclipse_flag
# 07-May-24 15:25:12: mms4_mec_moon_eclipse_flag
# 07-May-24 15:25:12: mms4_mec_r_eci
# 07-May-24 15:25:12: mms4_mec_v_eci
# 07-May-24 15:25:12: mms4_mec_r_gsm
# 07-May-24 15:25:12: mms4_mec_v_gsm
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_gsm
# 07-May-24 15:25:12: mms4_mec_r_geo
# 07-May-24 15:25:12: mms4_mec_v_geo
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_geo
# 07-May-24 15:25:12: mms4_mec_r_sm
# 07-May-24 15:25:12: mms4_mec_v_sm
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_sm
# 07-May-24 15:25:12: mms4_mec_r_gse
# 07-May-24 15:25:12: mms4_mec_v_gse
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_gse
# 07-May-24 15:25:12: mms4_mec_r_gse2000
# 07-May-24 15:25:12: mms4_mec_v_gse2000
# 07-May-24 15:25:12: mms4_mec_quat_eci_to_gse2000
# 07-May-24 15:25:12: mms4_mec_geod_lat
# 07-May-24 15:25:12: mms4_mec_geod_lon
# 07-May-24 15:25:12: mms4_mec_geod_height
# 07-May-24 15:25:12: mms4_mec_r_sun_de421_eci
# 07-May-24 15:25:12: mms4_mec_r_moon_de421_eci
# 07-May-24 15:25:12: mms4_mec_fieldline_type
# 07-May-24 15:25:12: mms4_mec_bsc_gsm
# 07-May-24 15:25:12: mms4_mec_loss_cone_angle_s
# 07-May-24 15:25:12: mms4_mec_loss_cone_angle_n
# 07-May-24 15:25:12: mms4_mec_pfs_geod_latlon
# 07-May-24 15:25:12: mms4_mec_pfn_geod_latlon
# 07-May-24 15:25:12: mms4_mec_pfs_gsm
# 07-May-24 15:25:12: mms4_mec_bfs_gsm
# 07-May-24 15:25:12: mms4_mec_pfn_gsm
# 07-May-24 15:25:12: mms4_mec_bfn_gsm
# 07-May-24 15:25:12: mms4_mec_pmin_gsm
# 07-May-24 15:25:12: mms4_mec_bmin_gsm
# 07-May-24 15:25:12: Interpolating the data to the MEC quaternion time stamps.
# 07-May-24 15:25:12: tinterpol (linear) was applied to: mms1_defeph_pos-itrp
# 07-May-24 15:25:12: Interpolating the data to the MEC quaternion time stamps.
# 07-May-24 15:25:12: tinterpol (linear) was applied to: mms2_defeph_pos-itrp
# 07-May-24 15:25:12: Interpolating the data to the MEC quaternion time stamps.
# 07-May-24 15:25:12: tinterpol (linear) was applied to: mms3_defeph_pos-itrp
# 07-May-24 15:25:12: Interpolating the data to the MEC quaternion time stamps.
# 07-May-24 15:25:12: tinterpol (linear) was applied to: mms4_defeph_pos-itrp

# %% [markdown]
# Figure 1 in Zhang's study shows the magnetic field, the ion velocity, electron density, and ion and electron energy spectra. We will make a few adjustments to the time range and plot options, to more closely match the published figure.

# %%
timespan('2017-07-26/07:10',40,'minutes')
# Zhang uses a linear scale for the density
options('mms1_des_numberdensity_fast','ylog',False)
fig1_vars=['mms1_fgm_b_gse_srvy_l2','mms1_dis_bulkv_gse_fast','mms1_des_numberdensity_fast','mms1_des_energyspectr_omni_fast','mms1_dis_energyspectr_omni_fast']
# We want to highlight some time intervals, to be explained below
trange_tailward = [time_double('2017-07-26/07:21:13'),time_double('2017-07-26/07:26:57')]
trange_reversal = [time_double('2017-07-26/07:26:57'),time_double('2017-07-26/07:30:00')]
trange_earthward = [time_double('2017-07-26/07:30:00'),time_double('2017-07-26/07:38:42')]
highlight(fig1_vars,trange_tailward,color='g',fill=True,alpha=0.2)
highlight(fig1_vars,trange_reversal,color='r',fill=True,alpha=0.2)
highlight(fig1_vars,trange_earthward,color='b',fill=True,alpha=0.2)
tplot(fig1_vars)

# %% [markdown]
# Zhang mentions several features evident in the above figure:
#
# > From 07:21:13–07:38:42 UT, strong, and turbulent fluctuations in the magnetic field   appeared (Figure 1(a)), and the high irregularity in the behavior of the magnetic field could suggest chaotic magnetic field lines. Concurrently, electron and ion fluxes showed characteristic energies with significant variations (Figures 1(d) and (e)). The density was depleted (Figure 1(c)). The ion flow velocity (see Figure 1(b)) reverses from tailward to earthward, suggesting an ongoing magnetic reconnection process.
#
# > [...] we divide the whole turbulence region (07:21:13–07:38:42 UT) into three areas according to ion flow velocity (Figure 1(b)): tailward flow region (07:21:13–07:26:57 UT); reversal flow region (07:26:57–07:30:00 UT); and earthward flow region (07:30:00–07:38:42 UT)
#
# The tailward, reversal, and earthward intervals are highlighted in green, red, and blue in the plot.

# %% [markdown]
# Now we will find the magnetic nulls during this event, and examine the field toplology for a couple of them:

# %%
mms_positions = ['mms1_defeph_pos_gse','mms2_defeph_pos_gse','mms3_defeph_pos_gse','mms4_defeph_pos_gse']
mms_fields = ['mms1_fgm_b_gse_brst_l2','mms2_fgm_b_gse_brst_l2','mms3_fgm_b_gse_brst_l2','mms4_fgm_b_gse_brst_l2']

null_vars = pyspedas.find_magnetic_nulls_fote(fields=mms_fields, positions=mms_positions, smooth_fields=True)
tplot(['null_bary_dist_types','null_fom','max_reconstruction_error'])
# Out:
# 07-May-24 15:25:16: tsmooth was applied to: mms1_fgm_b_gse_brst_l2_sm
# 07-May-24 15:25:20: tsmooth was applied to: mms2_fgm_b_gse_brst_l2_sm
# 07-May-24 15:25:23: tsmooth was applied to: mms3_fgm_b_gse_brst_l2_sm
# 07-May-24 15:25:27: tsmooth was applied to: mms4_fgm_b_gse_brst_l2_sm
# 07-May-24 15:25:27: tinterpol (linear) was applied to: pos1_i
# 07-May-24 15:25:27: tinterpol (linear) was applied to: pos2_i
# 07-May-24 15:25:27: tinterpol (linear) was applied to: pos3_i
# 07-May-24 15:25:27: tinterpol (linear) was applied to: pos4_i
# 07-May-24 15:25:27: tinterpol (linear) was applied to: b1_i
# 07-May-24 15:25:27: tinterpol (linear) was applied to: b2_i
# 07-May-24 15:25:27: tinterpol (linear) was applied to: b3_i
# 07-May-24 15:25:27: tinterpol (linear) was applied to: b4_i
# 07-May-24 15:25:44: Calculations completed

# %% [markdown]
# First, we'll look at a short time interval starting at 07:23:55.30:

# %%
timespan('2017-07-26/07:23:55.30',0.15,'seconds')
options('null_fom','yrange',[0.0,0.5])
tplot(['null_sc_distances','null_bary_dist_types','null_fom'])
# Out:
# 07-May-24 15:26:02: No data found in the time range: null_type3
# 07-May-24 15:26:02: No data found in the time range: null_type4
# 07-May-24 15:26:02: No data found in the time range: null_type5
# 07-May-24 15:26:02: No data found in the time range: null_type7
# 07-May-24 15:26:02: No data found in the time range: null_type8
# 07-May-24 15:26:02: No data found in the time range: null_type9
# 07-May-24 15:26:02: No data found in the time range: null_type10

# %% [markdown]
# The PySPEDAS analysis appears to agree quite well with Zhang's corresponding Figure 5. Both figures agree that the null had a Bs topological type, and the eta and xi values indicate mostly reliable position and topology determinations.

# %% [markdown]
# Now we'll look at the time interval 07:31:47.30 - 07:31:47.60:

# %%
timespan('2017-07-26/07:31:47.30',0.30,'seconds')
tplot(['null_sc_distances','null_bary_dist_types','null_fom'])
# Out:
# 07-May-24 15:26:02: No data found in the time range: null_type6
# 07-May-24 15:26:02: No data found in the time range: null_type7
# 07-May-24 15:26:02: No data found in the time range: null_type8
# 07-May-24 15:26:02: No data found in the time range: null_type9
# 07-May-24 15:26:02: No data found in the time range: null_type10

# %% [markdown]
# In this figure, PySPEDAS seems to place the null farther away from the tetrahedron than Zhang's analysis. (~500 km vs. ~50 km). Differences between the two figures may be due to different calibration, smoothing, interpolation, or other preprocessing steps performed in each analysis.  Both figures agree that the nulls are classified as mostly type A. Zhang has some of the nulls simplifying to type X, however it appears their simplification criterion is slightly different from that used by Fu and PySPEDAS.

# %% [markdown]
# References:
#
# Fu, H. S., A. Vaivads, Y. V. Khotyaintsev, V. Olshevsky, M. André, J. B. Cao, S. Y. Huang, A. Retinò, and G. Lapenta (2015), How to find magnetic nulls and reconstruct field topology with MMS data?. J. Geophys. Res. Space Physics, 120, 3758–3782. doi: 10.1002/2015JA021082.
#
# W. Z. Zhang, H. S. Fu, J. B. Cao, Z. Wang, and Y. Y. Liu (2023), Properties of the Turbulence and Topology in a Turbulent Magnetic Reconnection, ApJ, Volume 953, Number 1.
#  doi: 10.3847/1538-4357/acdacf
