# %%
import pyspedas

# %%
pyspedas.mms_overview_plot(date='2023-03-24',probe='1',ysize=15)
# Out:
# 07-May-24 15:41:31: Downloading remote index: http://themis.ssl.berkeley.edu/data/themis/thg/l1/mag/idx/2023/
# 07-May-24 15:41:31: File is current: themis_data/thg/l1/mag/idx/2023/thg_l1_idx_20230324_v01.cdf
# 07-May-24 15:41:33: Loading pydata/mms1/fgm/srvy/l2/2023/03/mms1_fgm_srvy_l2_20230324_v5.393.0.cdf
# 07-May-24 15:41:34: Loaded variables:
# 07-May-24 15:41:34: Epoch
# 07-May-24 15:41:34: mms1_fgm_b_gse_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_b_gsm_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_b_dmpa_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_b_bcs_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_flag_srvy_l2
# 07-May-24 15:41:34: Epoch_state
# 07-May-24 15:41:34: mms1_fgm_hirange_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_bdeltahalf_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_stemp_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_etemp_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_mode_srvy_l2
# 07-May-24 15:41:34: mms1_fgm_b_dmpa_srvy_l2_bvec
# 07-May-24 15:41:34: mms1_fgm_b_dmpa_srvy_l2_btot
# ...
